# %%
import pd_analysis as pda

# %%
import pandas as pd
#import alib.plots
import pandasql
import cPickle

# %%
import psycopg2

# %%
conn = psycopg2.connect(database="mousegenome", user="adrian", password="adrian", host="localhost")
import pandas.io.sql as sql

# %%
cur = conn.cursor()

# %%
cur.execute("select * from mm9_gene_motifs_distinct where max_motif_score >= 0.7")

# %%
mm9_gene_motifs = sql.read_frame("select * from mm9_gene_motifs_distinct where max_motif_score >= 0.7", conn)

# %%
mm9_gene_motifs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276795 entries, 0 to 276794
# Data columns (total 6 columns):
# genename           276795  non-null values
# chrom              276795  non-null values
# motif_type         276795  non-null values
# motif_name         276795  non-null values
# max_motif_score    276795  non-null values
# motif_count        276795  non-null values
# dtypes: float64(1), int64(1), object(4)

# %%
# load amalgamated table of statistics by probeset from pickled pandas file.  This file was generated by the pd_calc_stats notebook or script
cp_both_wide_info = cPickle.load( open("/data/adrian/Dropbox/Projects/Broad/PD_mouse/results/2013_july_9/cp_both_wide_info.pandas.pickle") )

# %%
reload(pda)
# Out:
# <module 'pd_analysis' from 'pd_analysis.pyc'>

# %%
factortypes = {}
for c in cp_both_wide_info.drop(["probe_id", "symbol", "gene_name"], axis=1).columns:
    for (k, v) in dict(pda.tm.d(c)).items():
        if isinstance(k, list):
            k = tuple(k)
        if isinstance(v, list):
            v = tuple(v)
        if factortypes.has_key(k):
            factortypes[k].add(v)
        else:
            factortypes[k] = set([v])

# %%
factortypes
# Out:
# {u'aim_lm': {u'bh', u'bonf', u'expr_coef', u'pval', u'rsq_adj', u'sign'},
#  u'cg': {u'ctrl', u'exp'},
#  u'cmp': {(u'6-OHDA, acuteHigh', u'6-OHDA, acuteSaline'),
#   (u'6-OHDA, chronicHigh', u'6-OHDA, acuteHigh'),
#   (u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow'),
#   (u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline'),
#   (u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline'),
#   (u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline')},
#  u'ct': {u'cp101', u'cp73'},
#  u'mc': {u'bh', u'bonf', u'nominal'},
#  u'mg': {u'allchronic', u'chronicHigh', u'chronicLow'},
#  u'st': {u'cv',
#   u'fc_means',
#   u'fc_medians',
#   u'mean',
#   u'median',
#   u'pval',
#   u'stddev',
#   u't'},
#  u'tt': {u'levene', u'student ttest', u'welch ttest'}}

# %%
test_info = [["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
fc_info = [["st", "fc_medians"]]
fc_threshold = log2(1.5)

summary = {}
top_tfs = {}

for fc_threshold in [1.5]:
    for comparison in factortypes["cmp"]:
        for celltype in factortypes["ct"]:
            #print comparison
            test_query = test_info + [ ["cmp", list(comparison)] ] + [ ["ct", celltype] ]
            fc_query = fc_info + [ ["cmp", list(comparison)] ] + [ ["ct", celltype] ]
            #td = dict(tm.d(c))
            if pda.tm.e(test_query) in set(cp_both_wide_info.columns):
                print pda.tm.e(test_query)
                current_group = cp_both_wide_info.select(
                        lambda x: cp_both_wide_info.ix[x, pda.tm.e(test_query) ] < 0.10
                              and abs(cp_both_wide_info.ix[x, pda.tm.e(fc_query) ]) >= log2(fc_threshold)
                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ) 
                k = pda.tm.e([ ["cmp", list(comparison)] ] 
                                 + [ ["ct", celltype] ]
                                 + [ ["dir", "any"]])
                try:
                    top_tfs[k] = countTFcombos( current_group, 1)
                except:
                    top_tfs[k] = None
                
                
                current_group = cp_both_wide_info.select(
                        lambda x: cp_both_wide_info.ix[x, pda.tm.e(test_query) ] < 0.10
                              and cp_both_wide_info.ix[x, pda.tm.e(fc_query) ] >= log2(fc_threshold)
                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ) 
                k = pda.tm.e([ ["cmp", list(comparison)] ] 
                                 + [ ["ct", celltype] ]
                                 + [ ["dir", "up"]])                
                
                try:
                    top_tfs[ k ] = countTFcombos( current_group, 1)
                except:
                    top_tfs[ k ] = None

                    
                current_group = cp_both_wide_info.select(
                        lambda x: cp_both_wide_info.ix[x, pda.tm.e(test_query) ] < 0.10
                              and cp_both_wide_info.ix[x, pda.tm.e(fc_query) ] <= -log2(fc_threshold)
                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ) 
                k = pda.tm.e([ ["cmp", list(comparison)] ] 
                                 + [ ["ct", celltype] ]
                                 + [ ["dir", "down"]])                
                try:
                    top_tfs[ k ] = countTFcombos( current_group, 1)
                except:
                    top_tfs[ k ] = None
                    
                
#                summary[ (celltype, comparison, fc_threshold, "changed") ] = len(uniqueSym( cp_both_wide_info.select(
#                        lambda x: cp_both_wide_info.ix[x, tm.e(test_query) ] < 0.10
#                              and abs(cp_both_wide_info.ix[x, tm.e(fc_query) ]) >= log2(fc_threshold)
#                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ).symbol ))
#                summary[ (celltype, comparison, fc_threshold, "up") ] = len(uniqueSym( cp_both_wide_info.select(
#                        lambda x: cp_both_wide_info.ix[x, tm.e(test_query) ] < 0.10
#                              and cp_both_wide_info.ix[x, tm.e(fc_query) ] >= log2(fc_threshold)
#                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ).symbol ))
#                summary[ (celltype, comparison, fc_threshold, "down") ] = len(uniqueSym( cp_both_wide_info.select(
#                        lambda x: cp_both_wide_info.ix[x, tm.e(test_query) ] < 0.10
#                              and cp_both_wide_info.ix[x, tm.e(fc_query) ] <= -log2(fc_threshold)
#                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ).symbol ))
            else:
                print "--"
# Out:
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 5489
# 1628
# 3861
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 3928
# 2851
# 1077
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 73865
# 33804
# 40276
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 2256
# 1628
# 628
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 108649
# 59944
# 49980
# --
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 108341
# 47501
# 61562
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 10738
# 6312
# 4457
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 12688
# 8096
# 4592
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 0
# 0
# 0
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 112094
# 38617
# 74058
# --

# %%
test_info = [["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
fc_info = [["st", "fc_medians"]]
fc_threshold = log2(1.5)

summary = {}
top_motifs = {}

for fc_threshold in [1.5]:
    for comparison in factortypes["cmp"]:
        for celltype in factortypes["ct"]:
            #print comparison
            test_query = test_info + [ ["cmp", list(comparison)] ] + [ ["ct", celltype] ]
            fc_query = fc_info + [ ["cmp", list(comparison)] ] + [ ["ct", celltype] ]
            #td = dict(tm.d(c))
            if pda.tm.e(test_query) in set(cp_both_wide_info.columns):
                print pda.tm.e(test_query)
                current_group = cp_both_wide_info.select(
                        lambda x: cp_both_wide_info.ix[x, pda.tm.e(test_query) ] < 0.10
                              and abs(cp_both_wide_info.ix[x, pda.tm.e(fc_query) ]) >= log2(fc_threshold)
                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ) 
                k = pda.tm.e([ ["cmp", list(comparison)] ] 
                                 + [ ["ct", celltype] ]
                                 + [ ["dir", "any"]])
                try:
                    top_motifs[k] = countMotifCombos( current_group, 1)
                except:
                    top_motifs[k] = None
                
                
                current_group = cp_both_wide_info.select(
                        lambda x: cp_both_wide_info.ix[x, pda.tm.e(test_query) ] < 0.10
                              and cp_both_wide_info.ix[x, pda.tm.e(fc_query) ] >= log2(fc_threshold)
                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ) 
                k = pda.tm.e([ ["cmp", list(comparison)] ] 
                                 + [ ["ct", celltype] ]
                                 + [ ["dir", "up"]])                
                
                try:
                    top_motifs[ k ] = countMotifCombos( current_group, 1)
                except:
                    top_motifs[ k ] = None

                    
                current_group = cp_both_wide_info.select(
                        lambda x: cp_both_wide_info.ix[x, pda.tm.e(test_query) ] < 0.10
                              and cp_both_wide_info.ix[x, pda.tm.e(fc_query) ] <= -log2(fc_threshold)
                                and isinstance(cp_both_wide_info.ix[x, "symbol" ], str) ) 
                k = pda.tm.e([ ["cmp", list(comparison)] ] 
                                 + [ ["ct", celltype] ]
                                 + [ ["dir", "down"]])                
                try:
                    top_motifs[ k ] = countMotifCombos( current_group, 1)
                except:
                    top_motifs[ k ] = None
# Out:
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 3460
# 1161
# 2299
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 2107
# 1388
# 719
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 44440
# 21454
# 23185
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 1281
# 962
# 319
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 66931
# 38759
# 28813
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 66192
# 29880
# 36795
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 6491
# 4233
# 2280
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 7263
# 4425
# 2838
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 0
# 0
# 0
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]
# 70370
# 23142
# 47617

# %%
ks = top_tfs.keys()
ks.sort()
for k in ks:
    print k
    if top_tfs[k] is None:
        print "n/a"
    else:
        print top_tfs[k][0:10]
# Out:
# [['cmp', [u'6-OHDA, acuteHigh', u'6-OHDA, acuteSaline']], ['ct', u'cp73'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 20     MYC   2238                  4727
# 95    CREM   1972                  4727
# 78    SPI1   1919                  4727
# 169   SOX2   1842                  4727
# 48   RUNX1   1838                  4727
# 26    FLI1   1808                  4727
# 89   HNF4A   1614                  4727
# 193   E2F1   1593                  4727
# 117  NANOG   1496                  4727
# 61    EGR1   1489                  4727
# [['cmp', [u'6-OHDA, acuteHigh', u'6-OHDA, acuteSaline']], ['ct', u'cp73'], ['dir', 'down']]
#          tf  count  total_genes_in_group
# 19      MYC   1560                  3338
# 114    SPI1   1305                  3338
# 38    RUNX1   1260                  3338
# 94     CREM   1253                  3338
# 25     FLI1   1241                  3338
# 168    SOX2   1222                  3338
# 88    HNF4A   1117                  3338
# 192    E2F1   1110                  3338
# 184  POU5F1   1003                  3338
# 60     EGR1    984                  3338
# [['cmp', [u'6-OHDA, acuteHigh', u'6-OHDA, acuteSaline']], ['ct', u'cp73'], ['dir', 'up']]
#         tf  count  total_genes_in_group
# 95    CREM    732                  1413
# 18     MYC    688                  1413
# 151   SOX2    628                  1413
# 114   SPI1    624                  1413
# 25   CREB1    610                  1413
# 37   RUNX1    587                  1413
# 24    FLI1    574                  1413
# 115  NANOG    521                  1413
# 60    EGR1    513                  1413
# 89   HNF4A    505                  1413
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, acuteHigh']], ['ct', u'cp73'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 21     MYC   2069                  4491
# 168   SOX2   1862                  4491
# 165   SPI1   1778                  4491
# 41   RUNX1   1772                  4491
# 97    CREM   1737                  4491
# 27    FLI1   1689                  4491
# 91   HNF4A   1547                  4491
# 64    EGR1   1502                  4491
# 82   STAT3   1470                  4491
# 192   E2F1   1453                  4491
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, acuteHigh']], ['ct', u'cp73'], ['dir', 'down']]
#         tf  count  total_genes_in_group
# 147   SOX2    876                  1852
# 20     MYC    869                  1852
# 38   RUNX1    788                  1852
# 78    SPI1    783                  1852
# 176   CREM    738                  1852
# 62    EGR1    736                  1852
# 116  STAT3    711                  1852
# 152   MITF    699                  1852
# 89   HNF4A    699                  1852
# 26    FLI1    697                  1852
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, acuteHigh']], ['ct', u'cp73'], ['dir', 'up']]
#          tf  count  total_genes_in_group
# 21      MYC   1226                  2681
# 80     SPI1   1018                  2681
# 97     CREM   1017                  2681
# 168    SOX2   1013                  2681
# 27     FLI1   1013                  2681
# 67    RUNX1   1012                  2681
# 193    E2F1    896                  2681
# 91    HNF4A    867                  2681
# 185  POU5F1    817                  2681
# 82    NANOG    803                  2681
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow']], ['ct', u'cp101'], ['dir', 'any']]
# n/a
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow']], ['ct', u'cp101'], ['dir', 'down']]
# n/a
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow']], ['ct', u'cp101'], ['dir', 'up']]
# n/a
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow']], ['ct', u'cp73'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 145   SOX2    223                   498
# 17     MYC    218                   498
# 110   SPI1    195                   498
# 111  STAT3    189                   498
# 61   RUNX1    186                   498
# 91    CREM    178                   498
# 108   TP63    176                   498
# 75   NANOG    175                   498
# 57    EGR1    175                   498
# 23    FLI1    174                   498
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow']], ['ct', u'cp73'], ['dir', 'down']]
#         tf  count  total_genes_in_group
# 16     MYC     87                   198
# 141   SOX2     76                   198
# 109   SPI1     76                   198
# 76   STAT3     75                   198
# 85   HNF4A     71                   198
# 35   RUNX1     67                   198
# 59    EGR1     66                   198
# 22    FLI1     63                   198
# 80    TP53     63                   198
# 110  NANOG     58                   198
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicLow']], ['ct', u'cp73'], ['dir', 'up']]
#         tf  count  total_genes_in_group
# 138   SOX2    147                   300
# 16     MYC    131                   300
# 107   TP63    125                   300
# 90    CREM    122                   300
# 35   RUNX1    119                   300
# 109   SPI1    119                   300
# 74   NANOG    117                   300
# 110  STAT3    114                   300
# 22    FLI1    111                   300
# 161  SUZ12    110                   300
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline']], ['ct', u'cp101'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 19     MYC    190                   408
# 146   SOX2    178                   408
# 60    EGR1    174                   408
# 65   RUNX1    164                   408
# 94    CREM    163                   408
# 25    FLI1    154                   408
# 115  STAT3    151                   408
# 181     AR    149                   408
# 114   SPI1    146                   408
# 88   HNF4A    143                   408
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline']], ['ct', u'cp101'], ['dir', 'down']]
#         tf  count  total_genes_in_group
# 177     AR     83                   166
# 60    EGR1     73                   166
# 18     MYC     71                   166
# 78   STAT3     70                   166
# 143   SOX2     68                   166
# 83    TP53     67                   166
# 147   MITF     62                   166
# 87   HNF4A     61                   166
# 64   RUNX1     61                   166
# 113  NANOG     61                   166
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline']], ['ct', u'cp101'], ['dir', 'up']]
#          tf  count  total_genes_in_group
# 17      MYC    120                   243
# 138    SOX2    111                   243
# 88     CREM    109                   243
# 37    RUNX1    104                   243
# 56     EGR1    101                   243
# 23     FLI1     96                   243
# 71     SPI1     90                   243
# 175  POU5F1     87                   243
# 82    HNF4A     83                   243
# 8     STAT3     81                   243
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline']], ['ct', u'cp73'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 18     MYC   1988                  4511
# 151   SOX2   1869                  4511
# 163   SPI1   1775                  4511
# 92    CREM   1757                  4511
# 38   RUNX1   1735                  4511
# 26    FLI1   1608                  4511
# 86   HNF4A   1568                  4511
# 59    EGR1   1511                  4511
# 77   STAT3   1499                  4511
# 113  NANOG   1454                  4511
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline']], ['ct', u'cp73'], ['dir', 'down']]
#         tf  count  total_genes_in_group
# 17     MYC   1145                  2668
# 147   SOX2   1103                  2668
# 164   SPI1   1007                  2668
# 39   RUNX1    988                  2668
# 88   HNF4A    954                  2668
# 94    CREM    902                  2668
# 78   STAT3    894                  2668
# 25    FLI1    893                  2668
# 59    EGR1    866                  2668
# 183     AR    855                  2668
# [['cmp', [u'6-OHDA, chronicHigh', u'6-OHDA, chronicSaline']], ['ct', u'cp73'], ['dir', 'up']]
#         tf  count  total_genes_in_group
# 93    CREM    868                  1871
# 18     MYC    860                  1871
# 75    SPI1    780                  1871
# 152   SOX2    778                  1871
# 38   RUNX1    761                  1871
# 25    FLI1    725                  1871
# 26   CREB1    701                  1871
# 59    EGR1    653                  1871
# 114  NANOG    641                  1871
# 87   HNF4A    625                  1871
# [['cmp', [u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline']], ['ct', u'cp101'], ['dir', 'any']]
#          tf  count  total_genes_in_group
# 14      MYC     42                    76
# 132    SOX2     41                    76
# 169  POU5F1     36                    76
# 88     CREM     35                    76
# 107   STAT3     33                    76
# 106    SPI1     31                    76
# 153    KLF4     30                    76
# 155   SUZ12     30                    76
# 53     EGR1     30                    76
# 73    NANOG     28                    76
# [['cmp', [u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline']], ['ct', u'cp101'], ['dir', 'down']]
#          tf  count  total_genes_in_group
# 123   SUZ12     13                    26
# 13      MYC     12                    26
# 135      AR     12                    26
# 107    SOX2     11                    26
# 136  POU5F1     10                    26
# 126   SIN3B      9                    26
# 44     EGR1      9                    26
# 70     CREM      9                    26
# 97    EP300      9                    26
# 61     TP53      9                    26
# [['cmp', [u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline']], ['ct', u'cp101'], ['dir', 'up']]
#          tf  count  total_genes_in_group
# 13      MYC     30                    50
# 129    SOX2     30                    50
# 82     CREM     26                    50
# 161  POU5F1     26                    50
# 100    SPI1     25                    50
# 101   STAT3     24                    50
# 11     KLF4     23                    50
# 158    REST     22                    50
# 31    RUNX1     21                    50
# 51     EGR1     21                    50
# [['cmp', [u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline']], ['ct', u'cp73'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 17     MYC   1307                  2980
# 147   SOX2   1284                  2980
# 78    SPI1   1191                  2980
# 40   RUNX1   1172                  2980
# 95    CREM   1160                  2980
# 89   HNF4A   1081                  2980
# 25    FLI1   1071                  2980
# 62    EGR1   1053                  2980
# 81   STAT3   1028                  2980
# 116  NANOG    993                  2980
# [['cmp', [u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline']], ['ct', u'cp73'], ['dir', 'down']]
#         tf  count  total_genes_in_group
# 152   SOX2    737                  1683
# 19     MYC    700                  1683
# 78    SPI1    646                  1683
# 38   RUNX1    642                  1683
# 90   HNF4A    638                  1683
# 81   STAT3    593                  1683
# 61    EGR1    576                  1683
# 25    FLI1    573                  1683
# 184     AR    569                  1683
# 147   MITF    558                  1683
# [['cmp', [u'6-OHDA, chronicLow', u'6-OHDA, chronicSaline']], ['ct', u'cp73'], ['dir', 'up']]
#         tf  count  total_genes_in_group
# 95    CREM    629                  1307
# 21     MYC    614                  1307
# 151   SOX2    553                  1307
# 77    SPI1    547                  1307
# 66   RUNX1    536                  1307
# 27    FLI1    498                  1307
# 28   CREB1    487                  1307
# 61    EGR1    478                  1307
# 115  NANOG    449                  1307
# 89   HNF4A    445                  1307
# [['cmp', [u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']], ['ct', u'cp101'], ['dir', 'any']]
#         tf  count  total_genes_in_group
# 161  SUZ12     73                   154
# 76   STAT3     71                   154
# 139   SOX2     63                   154
# 60    EGR1     59                   154
# 16     MYC     58                   154
# 56    MITF     57                   154
# 175     AR     57                   154
# 98   SMAD4     54                   154
# 81    TP53     53                   154
# 36   RUNX1     53                   154
# [['cmp', [u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']], ['ct', u'cp101'], ['dir', 'down']]
#          tf  count  total_genes_in_group
# 155      AR     22                    51
# 143   SUZ12     21                    51
# 52     EGR1     20                    51
# 122    SOX2     18                    51
# 69    STAT3     18                    51
# 72     TP53     16                    51
# 14      MYC     16                    51
# 97     SPI1     15                    51
# 126    MITF     15                    51
# 16   SETDB1     14                    51
# [['cmp', [u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']], ['ct', u'cp101'], ['dir', 'up']]
#         tf  count  total_genes_in_group
# 111  STAT3     53                   103
# 161  SUZ12     52                   103
# 143   SOX2     45                   103
# 98   SMAD4     45                   103
# 60   RUNX1     43                   103
# 52    MITF     42                   103
# 16     MYC     42                   103
# 174   REST     40                   103
# 134   MTF2     40                   103
# 92    CREM     39                   103
# [['cmp', [u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']], ['ct', u'cp73'], ['dir', 'any']]
#          tf  count  total_genes_in_group
# 138    SOX2     97                   220
# 160   SUZ12     96                   220
# 57     EGR1     94                   220
# 62    RUNX1     88                   220
# 175      AR     83                   220
# 108    TP63     82                   220
# 87    HNF4A     81                   220
# 82     TP53     76                   220
# 17      MYC     76                   220
# 176  POU5F1     76                   220
# [['cmp', [u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']], ['ct', u'cp73'], ['dir', 'down']]
#         tf  count  total_genes_in_group
# 57    EGR1     69                   150
# 140   SOX2     65                   150
# 157  SUZ12     63                   150
# 62   RUNX1     61                   150
# 171     AR     58                   150
# 136   MITF     57                   150
# 87   HNF4A     56                   150
# 111  STAT3     55                   150
# 82    TP53     54                   150
# 77   NANOG     53                   150
# [['cmp', [u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']], ['ct', u'cp73'], ['dir', 'up']]
#          tf  count  total_genes_in_group
# 152   SUZ12     33                    70
# 132    SOX2     32                    70
# 104    TP63     30                    70
# 60    RUNX1     27                    70
# 16      MYC     26                    70
# 83    HNF4A     25                    70
# 56     EGR1     25                    70
# 164      AR     25                    70
# 165  POU5F1     24                    70
# 148    SPI1     23                    70

# %%
import scipy.stats

# %%
scipy.stats.hypergeom.sf( 33, 22000, 5042, 70)
# Out:
# 2.2422561041688134e-06

# %%
total_genes = 22000

# %%
p = overlaps.apply( lambda x: (
      scipy.stats.hypergeom.sf(
          x.ix["match_count"]-1, # number of differentially expressed genes in set
          total_genes,           # total number of genes
          x.ix["size of set"],   # number of genes in current set
          len( test_set ))),     # total number of genes in test set
                               axis=1)
    p = pd.DataFrame(p, columns=["hypergeom p-val"])

# %%
for k in top_motifs.keys():
    if top_motifs[k] is not None:
        print k
        print top_motifs[k].merge(mm9_motif_gene_counts, 
                                                left_on="motif_name", 
                                                right_index=True).sort_index(by="pval", ascending=True)[0:20]g
# Out:
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["dir", "up"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 22              SP1.p2             SP1.p2     61                    70
# 101           PATZ1.p2           PATZ1.p2     53                    70
# 40              MAZ.p2             MAZ.p2     54                    70
# 13            TFDP1.p2           TFDP1.p2     43                    70
# 121          TFAP2B.p2          TFAP2B.p2     34                    70
# 8         MYFfamily.p2       MYFfamily.p2     19                    70
# 93            MYOD1.p2           MYOD1.p2     12                    70
# 125         E2F1..5.p2         E2F1..5.p2      7                    70
# 1              KLF4.p3            KLF4.p3     48                    70
# 54         SNAI1..3.p2        SNAI1..3.p2     23                    70
# 105            PAX5.p2            PAX5.p2     30                    70
# 41             HIC1.p2            HIC1.p2     25                    70
# 35   AHR_ARNT_ARNT2.p2  AHR_ARNT_ARNT2.p2     14                    70
# 123            MTF1.p2            MTF1.p2     19                    70
# 23            GTF2I.p2           GTF2I.p2     33                    70
# 99            ZBTB6.p2           ZBTB6.p2      9                    70
# 75             MAFB.p2            MAFB.p2     19                    70
# 113         NHLH1,2.p2         NHLH1,2.p2     17                    70
# 78         GTF2A1,2.p2        GTF2A1,2.p2      5                    70
# 9              NFE2.p2            NFE2.p2      5                    70
#
#              pval  motif_gene_count       motif_name_y
# 22   6.524818e-09             12044             SP1.p2
# 101  8.755004e-07             10334           PATZ1.p2
# 40   1.832899e-06             10878             MAZ.p2
# 13   2.185568e-05              8067           TFDP1.p2
# 121  2.460102e-04              6217          TFAP2B.p2
# 8    5.129105e-04              2672       MYFfamily.p2
# 93   8.193439e-04              1312           MYOD1.p2
# 125  8.254138e-04               480         E2F1..5.p2
# 1    9.716530e-04             10899            KLF4.p3
# 54   1.737088e-03              3921        SNAI1..3.p2
# 105  2.076146e-03              5810            PAX5.p2
# 41   2.331597e-03              4518            HIC1.p2
# 35   3.477976e-03              1983  AHR_ARNT_ARNT2.p2
# 123  3.609777e-03              3146            MTF1.p2
# 23   3.814036e-03              6874           GTF2I.p2
# 99   6.386588e-03              1063           ZBTB6.p2
# 75   7.421592e-03              3359            MAFB.p2
# 113  7.908756e-03              2886         NHLH1,2.p2
# 78   1.128368e-02               424        GTF2A1,2.p2
# 9    1.261010e-02               436            NFE2.p2
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["dir", "any"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 142          TFAP2B.p2          TFAP2B.p2    103                   220
# 14            TFDP1.p2           TFDP1.p2    119                   220
# 22              SP1.p2             SP1.p2    156                   220
# 46              MAZ.p2             MAZ.p2    143                   220
# 105      TFAP2{A,C}.p2      TFAP2{A,C}.p2    114                   220
# 88             MAFB.p2            MAFB.p2     60                   220
# 48             HIC1.p2            HIC1.p2     73                   220
# 119           PATZ1.p2           PATZ1.p2    135                   220
# 23            GTF2I.p2           GTF2I.p2     99                   220
# 63         SNAI1..3.p2        SNAI1..3.p2     64                   220
# 131         NHLH1,2.p2         NHLH1,2.p2     51                   220
# 39   AHR_ARNT_ARNT2.p2  AHR_ARNT_ARNT2.p2     39                   220
# 66       TCF4_dimer.p2      TCF4_dimer.p2     71                   220
# 120            LMO2.p2            LMO2.p2     33                   220
# 109           MYOD1.p2           MYOD1.p2     27                   220
# 144            MTF1.p2            MTF1.p2     50                   220
# 55             MZF1.p2            MZF1.p2    109                   220
# 65           ZFP161.p2          ZFP161.p2     51                   220
# 8         MYFfamily.p2       MYFfamily.p2     43                   220
# 146         E2F1..5.p2         E2F1..5.p2     13                   220
#
#              pval  motif_gene_count       motif_name_y
# 142  3.354500e-09              6217          TFAP2B.p2
# 14   9.385966e-08              8067           TFDP1.p2
# 22   5.780760e-07             12044             SP1.p2
# 46   2.114417e-06             10878             MAZ.p2
# 105  3.127564e-06              8076      TFAP2{A,C}.p2
# 88   3.139023e-06              3359            MAFB.p2
# 48   7.353396e-06              4518            HIC1.p2
# 119  1.145116e-05             10334           PATZ1.p2
# 23   1.177612e-05              6874           GTF2I.p2
# 63   2.587288e-05              3921        SNAI1..3.p2
# 131  2.947899e-05              2886         NHLH1,2.p2
# 39   3.240285e-05              1983  AHR_ARNT_ARNT2.p2
# 66   1.153681e-04              4716      TCF4_dimer.p2
# 120  1.841044e-04              1701            LMO2.p2
# 109  3.004484e-04              1312           MYOD1.p2
# 144  4.993781e-04              3146            MTF1.p2
# 55   6.592152e-04              8515            MZF1.p2
# 65   9.570400e-04              3321          ZFP161.p2
# 8    1.049781e-03              2672       MYFfamily.p2
# 146  1.147377e-03               480         E2F1..5.p2
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "any"]]
#                   motif_name             motif_name_x  count  \
# 14                  TFDP1.p2                 TFDP1.p2     45
# 81                   MAFB.p2                  MAFB.p2     25
# 108                 PATZ1.p2                 PATZ1.p2     50
# 96             TFAP2{A,C}.p2            TFAP2{A,C}.p2     42
# 34         AHR_ARNT_ARNT2.p2        AHR_ARNT_ARNT2.p2     16
# 22                    SP1.p2                   SP1.p2     55
# 127                TFAP2B.p2                TFAP2B.p2     34
# 114                 CREB1.p2                 CREB1.p2     11
# 40                   SPZ1.p2                  SPZ1.p2     14
# 99                   ATF6.p2                  ATF6.p2      9
# 42                    MAZ.p2                   MAZ.p2     50
# 124           SOX{8,9,10}.p2           SOX{8,9,10}.p2     10
# 48                    JUN.p2                   JUN.p2     12
# 64   HBP1_HMGB_SSRP1_UBTF.p2  HBP1_HMGB_SSRP1_UBTF.p2     13
# 1                    KLF4.p3                  KLF4.p3     49
# 97             NFY{A,B,C}.p2            NFY{A,B,C}.p2     18
# 116                  ZEB1.p2                  ZEB1.p2     15
# 60                 ZNF384.p2                ZNF384.p2      6
# 109                  LMO2.p2                  LMO2.p2     12
# 123            ATF5_CREB3.p2            ATF5_CREB3.p2     13
#
#      total_genes_in_group      pval  motif_gene_count             motif_name_y
# 14                     76  0.000052              8067                 TFDP1.p2
# 81                     76  0.000097              3359                  MAFB.p2
# 108                    76  0.000716             10334                 PATZ1.p2
# 96                     76  0.000738              8076            TFAP2{A,C}.p2
# 34                     76  0.001050              1983        AHR_ARNT_ARNT2.p2
# 22                     76  0.001204             12044                   SP1.p2
# 127                    76  0.001566              6217                TFAP2B.p2
# 114                    76  0.001610              1125                 CREB1.p2
# 40                     76  0.002449              1750                  SPZ1.p2
# 99                     76  0.002838               862                  ATF6.p2
# 42                     76  0.002916             10878                   MAZ.p2
# 124                    76  0.003843              1077           SOX{8,9,10}.p2
# 48                     76  0.004444              1473                   JUN.p2
# 64                     76  0.005099              1696  HBP1_HMGB_SSRP1_UBTF.p2
# 1                      76  0.006105             10899                  KLF4.p3
# 97                     76  0.008070              2875            NFY{A,B,C}.p2
# 116                    76  0.010211              2274                  ZEB1.p2
# 60                     76  0.012274               554                ZNF384.p2
# 109                    76  0.013366              1701                  LMO2.p2
# 123                    76  0.015628              1951            ATF5_CREB3.p2
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["dir", "down"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 96   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3   1076                  3338
# 155               NRF1.p2               NRF1.p2    752                  3338
# 16               TFDP1.p2              TFDP1.p2   1621                  3338
# 28                 SP1.p2                SP1.p2   2221                  3338
# 12                 EHF.p2                EHF.p2    733                  3338
# 68            ELF1,2,4.p2           ELF1,2,4.p2   1198                  3338
# 7               ZNF143.p2             ZNF143.p2    447                  3338
# 172             TFAP2B.p2             TFAP2B.p2   1264                  3338
# 57                HIC1.p2               HIC1.p2    970                  3338
# 128         TFAP2{A,C}.p2         TFAP2{A,C}.p2   1547                  3338
# 1                 KLF4.p3               KLF4.p3   1955                  3338
# 80              ZFP161.p2             ZFP161.p2    724                  3338
# 55                 MAZ.p2                MAZ.p2   1934                  3338
# 150               PAX5.p2               PAX5.p2   1133                  3338
# 164              PATZ1.p2              PATZ1.p2   1829                  3338
# 95             EGR1..3.p2            EGR1..3.p2    761                  3338
# 104                FEV.p2                FEV.p2    799                  3338
# 73              ETS1,2.p2             ETS1,2.p2    501                  3338
# 129         NFY{A,B,C}.p2         NFY{A,B,C}.p2    567                  3338
# 47      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    402                  3338
#
#              pval  motif_gene_count          motif_name_y
# 96   1.625563e-60              4645  ELK1,4_GABP{A,B1}.p3
# 155  4.106108e-53              3000               NRF1.p2
# 16   8.072881e-53              8067              TFDP1.p2
# 28   3.789479e-51             12044                SP1.p2
# 12   1.106859e-45              3024                EHF.p2
# 68   9.071453e-44              5707           ELF1,2,4.p2
# 7    2.280495e-39              1642             ZNF143.p2
# 172  2.878921e-39              6217             TFAP2B.p2
# 57   1.432830e-37              4518               HIC1.p2
# 128  1.798724e-35              8076         TFAP2{A,C}.p2
# 1    4.760335e-30             10899               KLF4.p3
# 80   9.451829e-29              3321             ZFP161.p2
# 55   8.351352e-27             10878                MAZ.p2
# 150  5.823536e-26              5810               PAX5.p2
# 164  5.486922e-23             10334              PATZ1.p2
# 95   1.176486e-16              3885            EGR1..3.p2
# 104  1.564528e-14              4192                FEV.p2
# 73   1.475258e-13              2463             ETS1,2.p2
# 129  9.134318e-13              2875         NFY{A,B,C}.p2
# 47   9.301654e-11              1983     AHR_ARNT_ARNT2.p2
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "down"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 17            TFDP1.p2           TFDP1.p2    805                  1683
# 172          TFAP2B.p2          TFAP2B.p2    633                  1683
# 129      TFAP2{A,C}.p2      TFAP2{A,C}.p2    775                  1683
# 29              SP1.p2             SP1.p2   1075                  1683
# 58             HIC1.p2            HIC1.p2    466                  1683
# 96          EGR1..3.p2         EGR1..3.p2    410                  1683
# 145           PATZ1.p2           PATZ1.p2    920                  1683
# 150            PAX5.p2            PAX5.p2    555                  1683
# 82           ZFP161.p2          ZFP161.p2    338                  1683
# 56              MAZ.p2             MAZ.p2    944                  1683
# 1              KLF4.p3            KLF4.p3    937                  1683
# 174            MTF1.p2            MTF1.p2    305                  1683
# 30            GTF2I.p2           GTF2I.p2    608                  1683
# 48   AHR_ARNT_ARNT2.p2  AHR_ARNT_ARNT2.p2    200                  1683
# 108            MAFB.p2            MAFB.p2    311                  1683
# 155            NRF1.p2            NRF1.p2    280                  1683
# 7            ZNF143.p2          ZNF143.p2    164                  1683
# 184     bHLH_family.p2     bHLH_family.p2    235                  1683
# 107          ZNF148.p2          ZNF148.p2    272                  1683
# 176         E2F1..5.p2         E2F1..5.p2     56                  1683
#
#              pval  motif_gene_count       motif_name_y
# 17   1.267879e-22              8067           TFDP1.p2
# 172  3.439279e-18              6217          TFAP2B.p2
# 129  1.975036e-16              8076      TFAP2{A,C}.p2
# 29   1.829579e-15             12044             SP1.p2
# 58   1.688551e-13              4518            HIC1.p2
# 96   3.311743e-13              3885         EGR1..3.p2
# 145  2.933514e-11             10334           PATZ1.p2
# 150  2.826399e-10              5810            PAX5.p2
# 82   5.787758e-09              3321          ZFP161.p2
# 56   7.870792e-09             10878             MAZ.p2
# 1    9.158677e-08             10899            KLF4.p3
# 174  3.524783e-06              3146            MTF1.p2
# 30   4.978784e-06              6874           GTF2I.p2
# 48   2.237619e-05              1983  AHR_ARNT_ARNT2.p2
# 108  1.112607e-04              3359            MAFB.p2
# 155  1.540419e-04              3000            NRF1.p2
# 7    2.076007e-04              1642          ZNF143.p2
# 184  7.188711e-04              2529     bHLH_family.p2
# 107  8.192776e-04              2982          ZNF148.p2
# 176  1.049334e-03               480         E2F1..5.p2
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "any"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 17               TFDP1.p2              TFDP1.p2   1538                  2980
# 173             TFAP2B.p2             TFAP2B.p2   1219                  2980
# 28                 SP1.p2                SP1.p2   2017                  2980
# 130         TFAP2{A,C}.p2         TFAP2{A,C}.p2   1475                  2980
# 146              PATZ1.p2              PATZ1.p2   1719                  2980
# 151               PAX5.p2               PAX5.p2   1070                  2980
# 57                 MAZ.p2                MAZ.p2   1784                  2980
# 97             EGR1..3.p2            EGR1..3.p2    772                  2980
# 1                 KLF4.p3               KLF4.p3   1784                  2980
# 59                HIC1.p2               HIC1.p2    867                  2980
# 83              ZFP161.p2             ZFP161.p2    659                  2980
# 109               MAFB.p2               MAFB.p2    651                  2980
# 167         ATF5_CREB3.p2         ATF5_CREB3.p2    418                  2980
# 70            ELF1,2,4.p2           ELF1,2,4.p2    987                  2980
# 29               GTF2I.p2              GTF2I.p2   1141                  2980
# 175               MTF1.p2               MTF1.p2    582                  2980
# 49      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    394                  2980
# 153               PAX2.p2               PAX2.p2    345                  2980
# 156               NRF1.p2               NRF1.p2    548                  2980
# 98   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3    795                  2980
#
#              pval  motif_gene_count          motif_name_y
# 17   7.375352e-72              8067              TFDP1.p2
# 173  8.323489e-58              6217             TFAP2B.p2
# 28   5.112842e-54             12044                SP1.p2
# 130  2.574002e-53              8076         TFAP2{A,C}.p2
# 146  1.409200e-36             10334              PATZ1.p2
# 151  5.093879e-35              5810               PAX5.p2
# 57   8.693720e-35             10878                MAZ.p2
# 97   3.141378e-34              3885            EGR1..3.p2
# 1    3.431916e-34             10899               KLF4.p3
# 59   2.510212e-33              4518               HIC1.p2
# 83   2.374613e-28              3321             ZFP161.p2
# 109  4.743462e-25              3359               MAFB.p2
# 167  7.465878e-24              1951         ATF5_CREB3.p2
# 70   3.045974e-21              5707           ELF1,2,4.p2
# 29   8.975623e-19              6874              GTF2I.p2
# 175  1.752052e-17              3146               MTF1.p2
# 49   1.437761e-16              1983     AHR_ARNT_ARNT2.p2
# 153  2.706949e-16              1690               PAX2.p2
# 156  2.641390e-15              3000               NRF1.p2
# 98   3.265509e-15              4645  ELK1,4_GABP{A,B1}.p3
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["dir", "any"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 16               TFDP1.p2              TFDP1.p2   2388                  4727
# 96   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3   1532                  4727
# 28                 SP1.p2                SP1.p2   3201                  4727
# 172             TFAP2B.p2             TFAP2B.p2   1858                  4727
# 128         TFAP2{A,C}.p2         TFAP2{A,C}.p2   2277                  4727
# 68            ELF1,2,4.p2           ELF1,2,4.p2   1720                  4727
# 12                 EHF.p2                EHF.p2   1024                  4727
# 155               NRF1.p2               NRF1.p2   1013                  4727
# 57                HIC1.p2               HIC1.p2   1392                  4727
# 1                 KLF4.p3               KLF4.p3   2823                  4727
# 150               PAX5.p2               PAX5.p2   1668                  4727
# 55                 MAZ.p2                MAZ.p2   2793                  4727
# 145              PATZ1.p2              PATZ1.p2   2673                  4727
# 81              ZFP161.p2             ZFP161.p2   1041                  4727
# 166         ATF5_CREB3.p2         ATF5_CREB3.p2    677                  4727
# 95             EGR1..3.p2            EGR1..3.p2   1151                  4727
# 7               ZNF143.p2             ZNF143.p2    569                  4727
# 107               MAFB.p2               MAFB.p2    992                  4727
# 154              CREB1.p2              CREB1.p2    409                  4727
# 47      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    637                  4727
#
#               pval  motif_gene_count          motif_name_y
# 16   1.636115e-107              8067              TFDP1.p2
# 96    2.500814e-95              4645  ELK1,4_GABP{A,B1}.p3
# 28    4.687757e-93             12044                SP1.p2
# 172   1.813149e-77              6217             TFAP2B.p2
# 128   1.774750e-74              8076         TFAP2{A,C}.p2
# 68    7.906920e-73              5707           ELF1,2,4.p2
# 12    3.050967e-65              3024                EHF.p2
# 155   1.017087e-63              3000               NRF1.p2
# 57    6.244297e-62              4518               HIC1.p2
# 1     1.156673e-56             10899               KLF4.p3
# 150   5.646193e-53              5810               PAX5.p2
# 55    5.359037e-51             10878                MAZ.p2
# 145   2.814602e-50             10334              PATZ1.p2
# 81    1.408429e-47              3321             ZFP161.p2
# 166   1.943342e-45              1951         ATF5_CREB3.p2
# 95    5.094276e-40              3885            EGR1..3.p2
# 7     1.152374e-37              1642             ZNF143.p2
# 107   4.004996e-33              3359               MAFB.p2
# 154   6.327255e-32              1125              CREB1.p2
# 47    3.947223e-31              1983     AHR_ARNT_ARNT2.p2
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["dir", "up"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 162         ATF5_CREB3.p2         ATF5_CREB3.p2    370                  1413
# 150              CREB1.p2              CREB1.p2    213                  1413
# 17               TFDP1.p2              TFDP1.p2    776                  1413
# 47                ATF4.p2               ATF4.p2    185                  1413
# 64                 JUN.p2                JUN.p2    229                  1413
# 125         TFAP2{A,C}.p2         TFAP2{A,C}.p2    743                  1413
# 30                 SP1.p2                SP1.p2    995                  1413
# 167             TFAP2B.p2             TFAP2B.p2    606                  1413
# 104               MAFB.p2               MAFB.p2    373                  1413
# 148               PAX2.p2               PAX2.p2    229                  1413
# 94   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3    465                  1413
# 141              PATZ1.p2              PATZ1.p2    857                  1413
# 146               PAX5.p2               PAX5.p2    544                  1413
# 93             EGR1..3.p2            EGR1..3.p2    398                  1413
# 1                 KLF4.p3               KLF4.p3    882                  1413
# 68            ELF1,2,4.p2           ELF1,2,4.p2    532                  1413
# 49      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    239                  1413
# 57                 MAZ.p2                MAZ.p2    873                  1413
# 59                HIC1.p2               HIC1.p2    429                  1413
# 128               ATF6.p2               ATF6.p2    124                  1413
#
#              pval  motif_gene_count          motif_name_y
# 162  7.387844e-89              1951         ATF5_CREB3.p2
# 150  8.669441e-49              1125              CREB1.p2
# 17   2.969305e-47              8067              TFDP1.p2
# 47   2.212795e-43               959               ATF4.p2
# 64   7.775682e-38              1473                JUN.p2
# 125  2.573794e-36              8076         TFAP2{A,C}.p2
# 30   9.354414e-36             12044                SP1.p2
# 167  3.472166e-34              6217             TFAP2B.p2
# 104  3.516363e-29              3359               MAFB.p2
# 148  1.165571e-28              1690               PAX2.p2
# 94   9.217744e-27              4645  ELK1,4_GABP{A,B1}.p3
# 141  1.082015e-26             10334              PATZ1.p2
# 146  6.115925e-25              5810               PAX5.p2
# 93   3.723957e-24              3885            EGR1..3.p2
# 1    5.793301e-24             10899               KLF4.p3
# 68   9.469722e-24              5707           ELF1,2,4.p2
# 49   1.226055e-22              1983     AHR_ARNT_ARNT2.p2
# 57   4.027788e-22             10878                MAZ.p2
# 59   1.111639e-19              4518               HIC1.p2
# 128  1.189393e-17               862               ATF6.p2
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "up"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 17               TFDP1.p2              TFDP1.p2    739                  1307
# 157         ATF5_CREB3.p2         ATF5_CREB3.p2    288                  1307
# 29                 SP1.p2                SP1.p2    950                  1307
# 163             TFAP2B.p2             TFAP2B.p2    592                  1307
# 122         TFAP2{A,C}.p2         TFAP2{A,C}.p2    708                  1307
# 30                KLF4.p3               KLF4.p3    855                  1307
# 56                 MAZ.p2                MAZ.p2    847                  1307
# 138              PATZ1.p2              PATZ1.p2    806                  1307
# 142               PAX5.p2               PAX5.p2    520                  1307
# 63                 JUN.p2                JUN.p2    194                  1307
# 103               MAFB.p2               MAFB.p2    343                  1307
# 145              CREB1.p2              CREB1.p2    161                  1307
# 67            ELF1,2,4.p2           ELF1,2,4.p2    501                  1307
# 46                ATF4.p2               ATF4.p2    141                  1307
# 80              ZFP161.p2             ZFP161.p2    324                  1307
# 92             EGR1..3.p2            EGR1..3.p2    364                  1307
# 93   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3    417                  1307
# 143               PAX2.p2               PAX2.p2    197                  1307
# 58                HIC1.p2               HIC1.p2    406                  1307
# 31               GTF2I.p2              GTF2I.p2    537                  1307
#
#              pval  motif_gene_count          motif_name_y
# 17   2.766183e-51              8067              TFDP1.p2
# 157  7.511132e-51              1951         ATF5_CREB3.p2
# 29   4.580839e-43             12044                SP1.p2
# 163  8.404339e-42              6217             TFAP2B.p2
# 122  4.021575e-40              8076         TFAP2{A,C}.p2
# 30   6.460663e-33             10899               KLF4.p3
# 56   6.830916e-31             10878                MAZ.p2
# 138  2.947481e-28             10334              PATZ1.p2
# 142  1.110680e-27              5810               PAX5.p2
# 63   7.338497e-27              1473                JUN.p2
# 103  2.531844e-26              3359               MAFB.p2
# 145  3.946564e-26              1125              CREB1.p2
# 67   2.514609e-24              5707           ELF1,2,4.p2
# 46   4.756208e-24               959               ATF4.p2
# 80   2.340293e-21              3321             ZFP161.p2
# 92   3.405817e-21              3885            EGR1..3.p2
# 93   3.659889e-21              4645  ELK1,4_GABP{A,B1}.p3
# 143  8.196294e-21              1690               PAX2.p2
# 58   1.419015e-20              4518               HIC1.p2
# 31   6.106786e-15              6874              GTF2I.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "any"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 17               TFDP1.p2              TFDP1.p2   2247                  4511
# 130         TFAP2{A,C}.p2         TFAP2{A,C}.p2   2208                  4511
# 173             TFAP2B.p2             TFAP2B.p2   1789                  4511
# 29                 SP1.p2                SP1.p2   3008                  4511
# 151               PAX5.p2               PAX5.p2   1624                  4511
# 59                HIC1.p2               HIC1.p2   1311                  4511
# 146              PATZ1.p2              PATZ1.p2   2543                  4511
# 57                 MAZ.p2                MAZ.p2   2647                  4511
# 1                 KLF4.p3               KLF4.p3   2645                  4511
# 83              ZFP161.p2             ZFP161.p2    980                  4511
# 97             EGR1..3.p2            EGR1..3.p2   1103                  4511
# 109               MAFB.p2               MAFB.p2    965                  4511
# 167         ATF5_CREB3.p2         ATF5_CREB3.p2    612                  4511
# 98   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3   1228                  4511
# 70            ELF1,2,4.p2           ELF1,2,4.p2   1458                  4511
# 156               NRF1.p2               NRF1.p2    841                  4511
# 49      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    588                  4511
# 175               MTF1.p2               MTF1.p2    864                  4511
# 69                MZF1.p2               MZF1.p2   2015                  4511
# 30               GTF2I.p2              GTF2I.p2   1651                  4511
#
#              pval  motif_gene_count          motif_name_y
# 17   1.379576e-91              8067              TFDP1.p2
# 130  9.551311e-80              8076         TFAP2{A,C}.p2
# 173  1.455436e-77              6217             TFAP2B.p2
# 29   1.602122e-74             12044                SP1.p2
# 151  7.394485e-58              5810               PAX5.p2
# 59   9.611257e-54              4518               HIC1.p2
# 146  7.434821e-46             10334              PATZ1.p2
# 57   2.395488e-44             10878                MAZ.p2
# 1    4.482023e-43             10899               KLF4.p3
# 83   2.255376e-41              3321             ZFP161.p2
# 97   7.606363e-39              3885            EGR1..3.p2
# 109  1.797565e-35              3359               MAFB.p2
# 167  1.172732e-32              1951         ATF5_CREB3.p2
# 98   1.836830e-28              4645  ELK1,4_GABP{A,B1}.p3
# 70   2.647970e-27              5707           ELF1,2,4.p2
# 156  1.249092e-26              3000               NRF1.p2
# 49   2.184007e-24              1983     AHR_ARNT_ARNT2.p2
# 175  2.436411e-24              3146               MTF1.p2
# 69   2.761562e-20              8515               MZF1.p2
# 30   4.128660e-18              6874              GTF2I.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["dir", "any"]]
#         motif_name   motif_name_x  count  total_genes_in_group          pval  \
# 153  ATF5_CREB3.p2  ATF5_CREB3.p2     84                   498  6.573432e-09
# 119  TFAP2{A,C}.p2  TFAP2{A,C}.p2    240                   498  7.673493e-08
# 27          SP1.p2         SP1.p2    330                   498  8.129220e-08
# 60          JUN.p2         JUN.p2     65                   498  1.811081e-07
# 15        TFDP1.p2       TFDP1.p2    236                   498  4.746567e-07
# 53          MAZ.p2         MAZ.p2    297                   498  2.460972e-06
# 44         ATF4.p2        ATF4.p2     45                   498  3.412928e-06
# 160      TFAP2B.p2      TFAP2B.p2    182                   498  3.031184e-05
# 135       PATZ1.p2       PATZ1.p2    277                   498  5.595770e-05
# 55         HIC1.p2        HIC1.p2    138                   498  6.637967e-05
# 42        EP300.p2       EP300.p2     57                   498  9.964664e-05
# 1          KLF4.p3        KLF4.p3    287                   498  1.517365e-04
# 99         MAFB.p2        MAFB.p2    106                   498  1.841743e-04
# 140        PAX5.p2        PAX5.p2    163                   498  8.939717e-04
# 8     MYFfamily.p2   MYFfamily.p2     84                   498  1.097839e-03
# 142       CREB1.p2       CREB1.p2     41                   498  1.909658e-03
# 47          MYB.p2         MYB.p2     29                   498  2.123022e-03
# 63         MZF1.p2        MZF1.p2    221                   498  5.140350e-03
# 58         TP53.p2        TP53.p2      8                   498  5.175432e-03
# 9          NFE2.p2        NFE2.p2     19                   498  5.262990e-03
#
#      motif_gene_count   motif_name_y
# 153              1951  ATF5_CREB3.p2
# 119              8076  TFAP2{A,C}.p2
# 27              12044         SP1.p2
# 60               1473         JUN.p2
# 15               8067       TFDP1.p2
# 53              10878         MAZ.p2
# 44                959        ATF4.p2
# 160              6217      TFAP2B.p2
# 135             10334       PATZ1.p2
# 55               4518        HIC1.p2
# 42               1508       EP300.p2
# 1               10899        KLF4.p3
# 99               3359        MAFB.p2
# 140              5810        PAX5.p2
# 8                2672   MYFfamily.p2
# 142              1125       CREB1.p2
# 47                720         MYB.p2
# 63               8515        MZF1.p2
# 58                117        TP53.p2
# 9                 436        NFE2.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["dir", "up"]]
#                     motif_name               motif_name_x  count  \
# 56                      JUN.p2                     JUN.p2     54
# 147              ATF5_CREB3.p2              ATF5_CREB3.p2     64
# 25                      SP1.p2                     SP1.p2    210
# 113              TFAP2{A,C}.p2              TFAP2{A,C}.p2    151
# 41                     ATF4.p2                    ATF4.p2     33
# 14                    TFDP1.p2                   TFDP1.p2    147
# 50                      MAZ.p2                     MAZ.p2    185
# 130                   PATZ1.p2                   PATZ1.p2    176
# 39                    EP300.p2                   EP300.p2     40
# 1                      KLF4.p3                    KLF4.p3    179
# 52                     HIC1.p2                    HIC1.p2     87
# 136                   CREB1.p2                   CREB1.p2     30
# 95                     ATF2.p2                    ATF2.p2     20
# 26                    GTF2I.p2                   GTF2I.p2    120
# 152                  TFAP2B.p2                  TFAP2B.p2    110
# 9                      NFE2.p2                    NFE2.p2     15
# 134                    PAX5.p2                    PAX5.p2    102
# 21   FOS_FOS{B,L1}_JUN{B,D}.p2  FOS_FOS{B,L1}_JUN{B,D}.p2     20
# 58                     MZF1.p2                    MZF1.p2    140
# 55                    FOXN1.p2                   FOXN1.p2     11
#
#      total_genes_in_group          pval  motif_gene_count  \
# 56                    300  2.320714e-11              1473
# 147                   300  2.761372e-11              1951
# 25                    300  3.753100e-08             12044
# 113                   300  8.567260e-07              8076
# 41                    300  1.094971e-06               959
# 14                    300  7.406257e-06              8067
# 50                    300  1.218175e-05             10878
# 130                   300  2.821462e-05             10334
# 39                    300  4.150171e-05              1508
# 1                     300  2.484429e-04             10899
# 52                    300  2.841070e-04              4518
# 136                   300  3.686455e-04              1125
# 95                    300  6.636135e-04               651
# 26                    300  7.597837e-04              6874
# 152                   300  9.011819e-04              6217
# 9                     300  1.024873e-03               436
# 134                   300  2.046832e-03              5810
# 21                    300  2.706194e-03               733
# 58                    300  2.826689e-03              8515
# 55                    300  3.614202e-03               309
#
#                   motif_name_y
# 56                      JUN.p2
# 147              ATF5_CREB3.p2
# 25                      SP1.p2
# 113              TFAP2{A,C}.p2
# 41                     ATF4.p2
# 14                    TFDP1.p2
# 50                      MAZ.p2
# 130                   PATZ1.p2
# 39                    EP300.p2
# 1                      KLF4.p3
# 52                     HIC1.p2
# 136                   CREB1.p2
# 95                     ATF2.p2
# 26                    GTF2I.p2
# 152                  TFAP2B.p2
# 9                      NFE2.p2
# 134                    PAX5.p2
# 21   FOS_FOS{B,L1}_JUN{B,D}.p2
# 58                     MZF1.p2
# 55                    FOXN1.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["dir", "any"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 16               TFDP1.p2              TFDP1.p2   2305                  4491
# 28                 SP1.p2                SP1.p2   3048                  4491
# 128         TFAP2{A,C}.p2         TFAP2{A,C}.p2   2206                  4491
# 171             TFAP2B.p2             TFAP2B.p2   1788                  4491
# 1                 KLF4.p3               KLF4.p3   2708                  4491
# 58                HIC1.p2               HIC1.p2   1313                  4491
# 144              PATZ1.p2              PATZ1.p2   2571                  4491
# 96   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3   1330                  4491
# 149               PAX5.p2               PAX5.p2   1592                  4491
# 56                 MAZ.p2                MAZ.p2   2657                  4491
# 81              ZFP161.p2             ZFP161.p2    988                  4491
# 68            ELF1,2,4.p2           ELF1,2,4.p2   1529                  4491
# 154               NRF1.p2               NRF1.p2    903                  4491
# 48      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    622                  4491
# 12                 EHF.p2                EHF.p2    857                  4491
# 107               MAFB.p2               MAFB.p2    925                  4491
# 95             EGR1..3.p2            EGR1..3.p2   1045                  4491
# 165         ATF5_CREB3.p2         ATF5_CREB3.p2    583                  4491
# 157            NHLH1,2.p2            NHLH1,2.p2    796                  4491
# 67                MZF1.p2               MZF1.p2   2016                  4491
#
#               pval  motif_gene_count          motif_name_y
# 16   1.504400e-112              8067              TFDP1.p2
# 28    2.018764e-89             12044                SP1.p2
# 128   1.705104e-81              8076         TFAP2{A,C}.p2
# 171   3.844446e-79              6217             TFAP2B.p2
# 1     3.027605e-59             10899               KLF4.p3
# 58    1.642059e-55              4518               HIC1.p2
# 144   4.062624e-54             10334              PATZ1.p2
# 96    3.061402e-52              4645  ELK1,4_GABP{A,B1}.p3
# 149   1.913971e-51              5810               PAX5.p2
# 56    1.162823e-48             10878                MAZ.p2
# 81    2.358256e-44              3321             ZFP161.p2
# 68    2.564819e-42              5707           ELF1,2,4.p2
# 154   2.684227e-42              3000               NRF1.p2
# 48    8.456296e-34              1983     AHR_ARNT_ARNT2.p2
# 12    1.446055e-29              3024                EHF.p2
# 107   2.257914e-27              3359               MAFB.p2
# 95    3.303631e-27              3885            EGR1..3.p2
# 165   1.430825e-25              1951         ATF5_CREB3.p2
# 157   1.934550e-23              2886            NHLH1,2.p2
# 67    1.467763e-21              8515               MZF1.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "up"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 163         ATF5_CREB3.p2         ATF5_CREB3.p2    387                  1871
# 17               TFDP1.p2              TFDP1.p2    998                  1871
# 28                 SP1.p2                SP1.p2   1333                  1871
# 126         TFAP2{A,C}.p2         TFAP2{A,C}.p2    996                  1871
# 168             TFAP2B.p2             TFAP2B.p2    799                  1871
# 1                 KLF4.p3               KLF4.p3   1192                  1871
# 148               PAX5.p2               PAX5.p2    732                  1871
# 55                 MAZ.p2                MAZ.p2   1176                  1871
# 143              PATZ1.p2              PATZ1.p2   1127                  1871
# 45                ATF4.p2               ATF4.p2    194                  1871
# 62                 JUN.p2                JUN.p2    259                  1871
# 57                HIC1.p2               HIC1.p2    585                  1871
# 151              CREB1.p2              CREB1.p2    214                  1871
# 68            ELF1,2,4.p2           ELF1,2,4.p2    689                  1871
# 105               MAFB.p2               MAFB.p2    456                  1871
# 94   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3    584                  1871
# 93             EGR1..3.p2            EGR1..3.p2    496                  1871
# 81              ZFP161.p2             ZFP161.p2    434                  1871
# 149               PAX2.p2               PAX2.p2    259                  1871
# 67                MZF1.p2               MZF1.p2    901                  1871
#
#              pval  motif_gene_count          motif_name_y
# 163  8.871256e-62              1951         ATF5_CREB3.p2
# 17   2.562365e-53              8067              TFDP1.p2
# 28   8.042536e-53             12044                SP1.p2
# 126  2.087644e-52              8076         TFAP2{A,C}.p2
# 168  1.172758e-44              6217             TFAP2B.p2
# 1    3.781178e-38             10899               KLF4.p3
# 148  2.163138e-36              5810               PAX5.p2
# 55   2.543508e-34             10878                MAZ.p2
# 143  1.801720e-33             10334              PATZ1.p2
# 45   3.553025e-31               959               ATF4.p2
# 62   3.905084e-31              1473                JUN.p2
# 57   1.515735e-30              4518               HIC1.p2
# 151  1.946884e-30              1125              CREB1.p2
# 68   1.206812e-27              5707           ELF1,2,4.p2
# 105  2.869131e-27              3359               MAFB.p2
# 94   5.773587e-27              4645  ELK1,4_GABP{A,B1}.p3
# 93   1.083340e-23              3885            EGR1..3.p2
# 81   2.301248e-22              3321             ZFP161.p2
# 149  6.037605e-22              1690               PAX2.p2
# 67   2.356899e-18              8515               MZF1.p2
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["dir", "up"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 48              JUN.p2             JUN.p2     18                   103
# 80             MAFB.p2            MAFB.p2     29                   103
# 81             ATF2.p2            ATF2.p2     10                   103
# 44             HIC1.p2            HIC1.p2     35                   103
# 127      ATF5_CREB3.p2      ATF5_CREB3.p2     19                   103
# 13            TFDP1.p2           TFDP1.p2     51                   103
# 53             REST.p3            REST.p3      3                   103
# 87       RXR{A,B,G}.p2      RXR{A,B,G}.p2     10                   103
# 140     bHLH_family.p2     bHLH_family.p2     20                   103
# 131          TFAP2B.p2          TFAP2B.p2     40                   103
# 97       TFAP2{A,C}.p2      TFAP2{A,C}.p2     49                   103
# 117           NFIL3.p2           NFIL3.p2      3                   103
# 8              NFE2.p2            NFE2.p2      6                   103
# 36   AHR_ARNT_ARNT2.p2  AHR_ARNT_ARNT2.p2     16                   103
# 136           HIF1A.p2           HIF1A.p2      8                   103
# 22            GTF2I.p2           GTF2I.p2     41                   103
# 101           MYOD1.p2           MYOD1.p2     11                   103
# 83         GTF2A1,2.p2        GTF2A1,2.p2      5                   103
# 45            FOSL2.p2           FOSL2.p2      5                   103
# 115            PAX5.p2            PAX5.p2     35                   103
#
#          pval  motif_gene_count       motif_name_y
# 48   0.000155              1473             JUN.p2
# 80   0.000584              3359            MAFB.p2
# 81   0.000958               651            ATF2.p2
# 44   0.001005              4518            HIC1.p2
# 127  0.001651              1951      ATF5_CREB3.p2
# 13   0.005073              8067           TFDP1.p2
# 53   0.005880                78            REST.p3
# 87   0.007389               866      RXR{A,B,G}.p2
# 140  0.012807              2529     bHLH_family.p2
# 131  0.013009              6217          TFAP2B.p2
# 97   0.015234              8076      TFAP2{A,C}.p2
# 117  0.015348               111           NFIL3.p2
# 8    0.016722               436            NFE2.p2
# 36   0.021861              1983  AHR_ARNT_ARNT2.p2
# 136  0.038864               821           HIF1A.p2
# 22   0.040178              6874           GTF2I.p2
# 101  0.043113              1312           MYOD1.p2
# 83   0.049160               424        GTF2A1,2.p2
# 45   0.049568               425           FOSL2.p2
# 115  0.053660              5810            PAX5.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "any"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 25              SP1.p2             SP1.p2    296                   408
# 154          TFAP2B.p2          TFAP2B.p2    185                   408
# 14            TFDP1.p2           TFDP1.p2    216                   408
# 115      TFAP2{A,C}.p2      TFAP2{A,C}.p2    214                   408
# 1              KLF4.p3            KLF4.p3    266                   408
# 72           ZFP161.p2          ZFP161.p2    111                   408
# 51              MAZ.p2             MAZ.p2    264                   408
# 130           PATZ1.p2           PATZ1.p2    249                   408
# 52             HIC1.p2            HIC1.p2    132                   408
# 135            PAX5.p2            PAX5.p2    158                   408
# 26            GTF2I.p2           GTF2I.p2    176                   408
# 60             MZF1.p2            MZF1.p2    208                   408
# 149      ATF5_CREB3.p2      ATF5_CREB3.p2     68                   408
# 124            HES1.p2            HES1.p2     55                   408
# 97             MAFB.p2            MAFB.p2    100                   408
# 96           ZNF148.p2          ZNF148.p2     90                   408
# 85          EGR1..3.p2         EGR1..3.p2    106                   408
# 57              JUN.p2             JUN.p2     50                   408
# 43   AHR_ARNT_ARNT2.p2  AHR_ARNT_ARNT2.p2     62                   408
# 41             ATF4.p2            ATF4.p2     36                   408
#
#              pval  motif_gene_count       motif_name_y
# 25   6.475633e-14             12044             SP1.p2
# 154  9.580949e-14              6217          TFAP2B.p2
# 14   1.056250e-11              8067           TFDP1.p2
# 115  4.602741e-11              8076      TFAP2{A,C}.p2
# 1    8.933986e-11             10899            KLF4.p3
# 72   1.519666e-10              3321          ZFP161.p2
# 51   2.598962e-10             10878             MAZ.p2
# 130  6.086178e-09             10334           PATZ1.p2
# 52   1.124119e-08              4518            HIC1.p2
# 135  2.812130e-08              5810            PAX5.p2
# 26   2.268056e-07              6874           GTF2I.p2
# 60   2.559966e-07              8515            MZF1.p2
# 149  2.828976e-07              1951      ATF5_CREB3.p2
# 124  4.101099e-07              1458            HES1.p2
# 97   6.044684e-07              3359            MAFB.p2
# 96   1.503784e-06              2982          ZNF148.p2
# 85   1.458209e-05              3885         EGR1..3.p2
# 57   2.609123e-05              1473             JUN.p2
# 43   3.180658e-05              1983  AHR_ARNT_ARNT2.p2
# 41   5.232512e-05               959            ATF4.p2
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["dir", "down"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 72       NFY{A,B,C}.p2      NFY{A,B,C}.p2     14                    51
# 18            GTF2I.p2           GTF2I.p2     25                    51
# ...
# 11   0.000007              8067           TFDP1.p2
# 39   0.000111             10878             MAZ.p2
# 118  0.000113              6217          TFAP2B.p2
# 0    0.000117             10899            KLF4.p3
# 88   0.000242              8076      TFAP2{A,C}.p2
# 73   0.000254              3359            MAFB.p2
# 37   0.001609              1750            SPZ1.p2
# 84   0.001696              1493         NR5A1,2.p2
# 46   0.001835              8515            MZF1.p2
# 115  0.002765              1077     SOX{8,9,10}.p2
# 106  0.003611              1125           CREB1.p2
# 94   0.003683               456      FOX{D1,D2}.p2
# 89   0.003883              2875      NFY{A,B,C}.p2
# 108  0.004177              2274            ZEB1.p2
# 31   0.004287              1983  AHR_ARNT_ARNT2.p2
# 45   0.005452              1473             JUN.p2
# 111  0.005696              1483           SOX17.p2
# 23   0.007364              1832            GFI1.p2
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["dir", "down"]]
#                     motif_name               motif_name_x  count  \
# 137                  TFAP2B.p2                  TFAP2B.p2     69
# 101              TFAP2{A,C}.p2              TFAP2{A,C}.p2     82
# 85                     MAFB.p2                    MAFB.p2     41
# 14                    TFDP1.p2                   TFDP1.p2     76
# 48                     HIC1.p2                    HIC1.p2     48
# 24                    GTF2I.p2                   GTF2I.p2     66
# 126                 NHLH1,2.p2                 NHLH1,2.p2     34
# 116                    LMO2.p2                    LMO2.p2     23
# 65               TCF4_dimer.p2              TCF4_dimer.p2     48
# 39           AHR_ARNT_ARNT2.p2          AHR_ARNT_ARNT2.p2     25
# 62                 SNAI1..3.p2                SNAI1..3.p2     41
# 148             bHLH_family.p2             bHLH_family.p2     28
# 54                     MZF1.p2                    MZF1.p2     73
# 64                   ZFP161.p2                  ZFP161.p2     34
# 46                      MAZ.p2                     MAZ.p2     89
# 109                    HES1.p2                    HES1.p2     18
# 19   FOS_FOS{B,L1}_JUN{B,D}.p2  FOS_FOS{B,L1}_JUN{B,D}.p2     11
# 135                  POU5F1.p2                  POU5F1.p2     12
# 23                      SP1.p2                     SP1.p2     95
# 139                    MTF1.p2                    MTF1.p2     31
#
#      total_genes_in_group      pval  motif_gene_count  \
# 137                   150  0.000003              6217
# 101                   150  0.000005              8076
# 85                    150  0.000101              3359
# 14                    150  0.000307              8067
# 48                    150  0.000632              4518
# 24                    150  0.000664              6874
# 126                   150  0.000891              2886
# 116                   150  0.001211              1701
# 65                    150  0.001656              4716
# 39                    150  0.001940              1983
# 62                    150  0.002497              3921
# 148                   150  0.006520              2529
# 54                    150  0.008063              8515
# 64                    150  0.008795              3321
# 46                    150  0.009310             10878
# 109                   150  0.010510              1458
# 19                    150  0.011882               733
# 135                   150  0.016545               873
# 23                    150  0.020183             12044
# 139                   150  0.020727              3146
#
#                   motif_name_y
# 137                  TFAP2B.p2
# 101              TFAP2{A,C}.p2
# 85                     MAFB.p2
# 14                    TFDP1.p2
# 48                     HIC1.p2
# 24                    GTF2I.p2
# 126                 NHLH1,2.p2
# 116                    LMO2.p2
# 65               TCF4_dimer.p2
# 39           AHR_ARNT_ARNT2.p2
# 62                 SNAI1..3.p2
# 148             bHLH_family.p2
# 54                     MZF1.p2
# 64                   ZFP161.p2
# 46                      MAZ.p2
# 109                    HES1.p2
# 19   FOS_FOS{B,L1}_JUN{B,D}.p2
# 135                  POU5F1.p2
# 23                      SP1.p2
# 139                    MTF1.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["dir", "down"]]
#                   motif_name             motif_name_x  count  \
# 92                   MAFB.p2                  MAFB.p2     46
# 75   HBP1_HMGB_SSRP1_UBTF.p2  HBP1_HMGB_SSRP1_UBTF.p2     27
# 8               MYFfamily.p2             MYFfamily.p2     37
# 69                   ALX1.p2                  ALX1.p2      5
# 79                GLI1..3.p2               GLI1..3.p2     11
# 149                TFAP2B.p2                TFAP2B.p2     72
# 16                  TFDP1.p2                 TFDP1.p2     89
# 111            TFAP2{A,C}.p2            TFAP2{A,C}.p2     89
# 61               ELF1,2,4.p2              ELF1,2,4.p2     66
# 62                   SOX5.p2                  SOX5.p2     12
# 73             TCF4_dimer.p2            TCF4_dimer.p2     55
# 55                   TP53.p2                  TP53.p2      4
# 51                    MAZ.p2                   MAZ.p2    112
# 45                    MYB.p2                   MYB.p2     12
# 47                PRRX1,2.p2               PRRX1,2.p2     35
# 85                   ESR1.p2                  ESR1.p2      7
# 18        RXRA_VDR{dimer}.p2       RXRA_VDR{dimer}.p2      2
# 52                   HIC1.p2                  HIC1.p2     51
# 103                 NR1H4.p2                 NR1H4.p2      4
# 117            FOX{D1,D2}.p2            FOX{D1,D2}.p2      8
#
#      total_genes_in_group      pval  motif_gene_count             motif_name_y
# 92                    198  0.001983              3359                  MAFB.p2
# 75                    198  0.002709              1696  HBP1_HMGB_SSRP1_UBTF.p2
# 8                     198  0.004924              2672             MYFfamily.p2
# 69                    198  0.004977               122                  ALX1.p2
# 79                    198  0.006683               510               GLI1..3.p2
# 149                   198  0.007842              6217                TFAP2B.p2
# 16                    198  0.009880              8067                 TFDP1.p2
# 111                   198  0.010206              8076            TFAP2{A,C}.p2
# 61                    198  0.012065              5707              ELF1,2,4.p2
# 62                    198  0.013574               641                  SOX5.p2
# 73                    198  0.020212              4716            TCF4_dimer.p2
# 55                    198  0.021469               117                  TP53.p2
# 51                    198  0.026001             10878                   MAZ.p2
# 45                    198  0.030181               720                   MYB.p2
# 47                    198  0.041091              2894               PRRX1,2.p2
# 85                    198  0.042716               356                  ESR1.p2
# 18                    198  0.043686                37       RXRA_VDR{dimer}.p2
# 52                    198  0.043786              4518                  HIC1.p2
# 103                   198  0.047807               151                 NR1H4.p2
# 117                   198  0.054795               456            FOX{D1,D2}.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "up"]]
#         motif_name   motif_name_x  count  total_genes_in_group          pval  \
# 24          SP1.p2         SP1.p2    196                   243  1.449396e-17
# 1          KLF4.p3        KLF4.p3    176                   243  2.444616e-13
# 49          MAZ.p2         MAZ.p2    172                   243  9.335942e-12
# 14        TFDP1.p2       TFDP1.p2    140                   243  2.123488e-11
# 146      TFAP2B.p2      TFAP2B.p2    117                   243  3.291692e-11
# 129        PAX5.p2        PAX5.p2    108                   243  8.544552e-10
# 125       PATZ1.p2       PATZ1.p2    161                   243  8.803213e-10
# 111  TFAP2{A,C}.p2  TFAP2{A,C}.p2    135                   243  1.482120e-09
# 70       ZFP161.p2      ZFP161.p2     73                   243  2.216096e-09
# 112  NFY{A,B,C}.p2  NFY{A,B,C}.p2     62                   243  1.146821e-07
# 58         MZF1.p2        MZF1.p2    133                   243  2.643552e-07
# 93         MAFB.p2        MAFB.p2     67                   243  5.623453e-07
# 119        HES1.p2        HES1.p2     38                   243  6.856488e-07
# 92       ZNF148.p2      ZNF148.p2     61                   243  9.407918e-07
# 50         HIC1.p2        HIC1.p2     81                   243  1.961127e-06
# 82      EGR1..3.p2     EGR1..3.p2     72                   243  2.944742e-06
# 135     NHLH1,2.p2     NHLH1,2.p2     56                   243  1.481063e-05
# 133        ZEB1.p2        ZEB1.p2     47                   243  1.767771e-05
# 142  ATF5_CREB3.p2  ATF5_CREB3.p2     42                   243  2.091524e-05
# 148        MTF1.p2        MTF1.p2     59                   243  2.280708e-05
#
#      motif_gene_count   motif_name_y
# 24              12044         SP1.p2
# 1               10899        KLF4.p3
# 49              10878         MAZ.p2
# 14               8067       TFDP1.p2
# 146              6217      TFAP2B.p2
# 129              5810        PAX5.p2
# 125             10334       PATZ1.p2
# 111              8076  TFAP2{A,C}.p2
# 70               3321      ZFP161.p2
# 112              2875  NFY{A,B,C}.p2
# 58               8515        MZF1.p2
# 93               3359        MAFB.p2
# 119              1458        HES1.p2
# 92               2982      ZNF148.p2
# 50               4518        HIC1.p2
# 82               3885     EGR1..3.p2
# 135              2886     NHLH1,2.p2
# 133              2274        ZEB1.p2
# 142              1951  ATF5_CREB3.p2
# 148              3146        MTF1.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["dir", "down"]]
#             motif_name       motif_name_x  count  total_genes_in_group  \
# 16            TFDP1.p2           TFDP1.p2    969                  1852
# 129      TFAP2{A,C}.p2      TFAP2{A,C}.p2    932                  1852
# 182             SP1.p2             SP1.p2   1249                  1852
# 170          TFAP2B.p2          TFAP2B.p2    739                  1852
# 162           PATZ1.p2           PATZ1.p2   1087                  1852
# 164      ATF5_CREB3.p2      ATF5_CREB3.p2    299                  1852
# 48   AHR_ARNT_ARNT2.p2  AHR_ARNT_ARNT2.p2    296                  1852
# 56              MAZ.p2             MAZ.p2   1113                  1852
# 29            GTF2I.p2           GTF2I.p2    764                  1852
# 1              KLF4.p3            KLF4.p3   1111                  1852
# 67             MZF1.p2            MZF1.p2    897                  1852
# 58             HIC1.p2            HIC1.p2    532                  1852
# 149            PAX5.p2            PAX5.p2    649                  1852
# 95          EGR1..3.p2         EGR1..3.p2    464                  1852
# 81           ZFP161.p2          ZFP161.p2    408                  1852
# 152           CREB1.p2           CREB1.p2    174                  1852
# 107            MAFB.p2            MAFB.p2    405                  1852
# 46             ATF4.p2            ATF4.p2    146                  1852
# 172            MTF1.p2            MTF1.p2    369                  1852
# 151            PAX2.p2            PAX2.p2    217                  1852
#
#              pval  motif_gene_count       motif_name_y
# 16   8.572635e-47              8067           TFDP1.p2
# 129  5.724898e-36              8076      TFAP2{A,C}.p2
# 182  2.285206e-31             12044             SP1.p2
# 170  1.082588e-29              6217          TFAP2B.p2
# 162  2.968391e-26             10334           PATZ1.p2
# 164  3.556266e-26              1951      ATF5_CREB3.p2
# 48   5.006481e-24              1983  AHR_ARNT_ARNT2.p2
# 56   4.732741e-22             10878             MAZ.p2
# 29   1.311548e-21              6874           GTF2I.p2
# 1    2.756503e-21             10899            KLF4.p3
# 67   3.870983e-19              8515            MZF1.p2
# 58   1.055470e-18              4518            HIC1.p2
# 149  6.220501e-18              5810            PAX5.p2
# 95   3.941245e-17              3885         EGR1..3.p2
# 81   6.550405e-17              3321          ZFP161.p2
# 152  1.159899e-15              1125           CREB1.p2
# 107  1.983111e-15              3359            MAFB.p2
# 46   9.546676e-13               959            ATF4.p2
# 172  2.707394e-12              3146            MTF1.p2
# 151  9.095598e-11              1690            PAX2.p2
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "down"]]
#                motif_name          motif_name_x  count  total_genes_in_group  \
# 16               TFDP1.p2              TFDP1.p2   1262                  2668
# 172             TFAP2B.p2             TFAP2B.p2   1001                  2668
# 129         TFAP2{A,C}.p2         TFAP2{A,C}.p2   1227                  2668
# 28                 SP1.p2                SP1.p2   1694                  2668
# 58                HIC1.p2               HIC1.p2    735                  2668
# 150               PAX5.p2               PAX5.p2    903                  2668
# 82              ZFP161.p2             ZFP161.p2    551                  2668
# 96             EGR1..3.p2            EGR1..3.p2    613                  2668
# 145              PATZ1.p2              PATZ1.p2   1433                  2668
# 56                 MAZ.p2                MAZ.p2   1489                  2668
# 155               NRF1.p2               NRF1.p2    479                  2668
# 7               ZNF143.p2             ZNF143.p2    287                  2668
# 174               MTF1.p2               MTF1.p2    495                  2668
# 108               MAFB.p2               MAFB.p2    519                  2668
# 1                 KLF4.p3               KLF4.p3   1471                  2668
# 48      AHR_ARNT_ARNT2.p2     AHR_ARNT_ARNT2.p2    322                  2668
# 107             ZNF148.p2             ZNF148.p2    440                  2668
# 97   ELK1,4_GABP{A,B1}.p3  ELK1,4_GABP{A,B1}.p3    654                  2668
# 158            NHLH1,2.p2            NHLH1,2.p2    423                  2668
# 69            ELF1,2,4.p2           ELF1,2,4.p2    781                  2668
#
#              pval  motif_gene_count          motif_name_y
# 16   2.401273e-33              8067              TFDP1.p2
# 172  1.178356e-28              6217             TFAP2B.p2
# 129  6.538212e-26              8076         TFAP2{A,C}.p2
# 28   1.094470e-22             12044                SP1.p2
# 58   1.153060e-20              4518               HIC1.p2
# 150  6.079912e-20              5810               PAX5.p2
# 82   1.084339e-16              3321             ZFP161.p2
# 96   5.296523e-14              3885            EGR1..3.p2
# 145  6.267173e-14             10334              PATZ1.p2
# 56   1.292221e-12             10878                MAZ.p2
# 155  1.222110e-11              3000               NRF1.p2
# 7    3.090739e-11              1642             ZNF143.p2
# 174  5.164735e-11              3146               MTF1.p2
# 108  2.742261e-10              3359               MAFB.p2
# 1    3.919890e-10             10899               KLF4.p3
# 48   9.134365e-09              1983     AHR_ARNT_ARNT2.p2
# 107  2.198902e-06              2982             ZNF148.p2
# 97   3.455691e-06              4645  ELK1,4_GABP{A,B1}.p3
# 158  7.168112e-06              2886            NHLH1,2.p2
# 69   1.881445e-05              5707           ELF1,2,4.p2

# %%
for k in top_tfs.keys():
    if top_tfs[k] is not None:
        top_tfs[k]["pval"] = top_tfs[k].merge(tf_target_counts, left_on="tf", right_index=True).apply( lambda x: (
         scipy.stats.hypergeom.sf(
              x.ix["c[ount"]-1, # number of differentially expressed genes in set
              total_genes,           # total number of genes
              x.ix["chea_target_count"],   # number of genes in current set
              x.ix["total_genes_in_group"])),     # total number of genes in test set
            axis=1 )

# %%
for k in top_motifs.keys():
    if top_motifs[k] is not None:
        top_motifs[k]["pval"] = top_motifs[k].merge(mm9_motif_gene_counts, left_on="motif_name", right_index=True).apply( lambda x: (
         scipy.stats.hypergeom.sf(
              x.ix["count"]-1, # number of differentially expressed genes in set
              total_genes,           # total number of genes
              x.ix["motif_gene_count"],   # number of genes in current set
              x.ix["total_genes_in_group"])),     # total number of genes in test set
            axis=1 )

# %%
"_".join( [str(z[1]) for z in pda.tm.d(k)] )
# Out:
# "[u'6-OHDA, chronicSaline', u'Ascorbate, chronicSaline']_cp73_up"

# %%
e = pd.ExcelWriter("/data/adrian/Dropbox/pd_tf_enrichment_20130820.xls")

# %%
e = open("/data/adrian/Dropbox/pd_tf_enrichment_20130821.html","w")

# %%
for k in top_tfs.keys():
    if top_tfs[k] is not None:
        print k
        t = top_tfs[k].sort_index(by="pval", ascending=True)[0:30].merge(tf_target_counts, left_on="tf", right_index=True).drop(["tf_x", "tf_y"], axis=1)
        e.write("<hr>")
        e.write("<h2>" + k + "</h2>")
        
        m = top_motifs[k].merge(mm9_motif_gene_counts, left_on="motif_name", right_index=True).sort_index(by="pval", ascending=True)[0:30].drop(["motif_name_x", "motif_name_y"], axis=1)
        e.write("<table>")
        e.write("<tr><th> top 30 overrepresented associations from CHEA </th> <th> top 30 over-represented tf binding motifs (SwissRegulon) </th></tr>")
        e.write("<tr><td>" + t.to_html() + "</td>" + "<td style='padding-left: 25px'>" + m.to_html() + "</td></tr></table>")
# Out:
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["dir", "any"]]
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "any"]]
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "any"]]
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["dir", "any"]]
# [["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "any"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["dir", "any"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["dir", "any"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "any"]]
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["dir", "any"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["dir", "up"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["dir", "down"]]
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["dir", "down"]]

# %%
e.close()

# %%
patterns = cp_both_wide_info[ [c for c in pda.tm.m([("cmp"), 
          ("st", "pval"), 
          ("mc", "bh"), 
          ("tt", "welch ttest")], cp_both_wide_info.columns)] ]  < 0.10
# Out:
# not an encoded tag list
# not an encoded tag list
# not an encoded tag list

# %%
[c for c in pda.tm.m([("cmp"), 
          ("st", "pval"), 
          ("mc", "bh"), 
          ("tt", "welch ttest")], cp_both_wide_info.columns)]
# Out:
# not an encoded tag list
# not an encoded tag list
# not an encoded tag list
# ['[["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]']

# %%
table_fc_threshold = log2(1.5)
cn_cp73_bh_ttest_pval = pda.tm.e([("cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]), 
        ("ct", "cp73"), ("mc", "bh"), ("st", "pval"), ("tt", "welch ttest")])
cn_cp73_median_foldchange = pda.tm.e([  ("cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]), 
        ("ct", "cp73"), ("st", "fc_medians")])

cp73_dopamine_depletion_up = (cp_both_wide_info.select(
    lambda x: cp_both_wide_info.ix[x, cn_cp73_bh_ttest_pval] < 0.10
    and cp_both_wide_info.ix[x, cn_cp73_median_foldchange] >= table_fc_threshold
))[["probe_id", "symbol", "gene_name", 
    cn_cp73_bh_ttest_pval,
    cn_cp73_median_foldchange
    ]].sort_index(by=cn_cp73_median_foldchange, ascending=False)

# %%
cn_cp73_chronicHigh_bh_ttest_pval = pda.tm.e([  ("cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]),
            ("ct", "cp73"),
            ("mc", "bh"),
            ("st", "pval"),
            ("tt", "welch ttest")
        ])

cn_cp73_chronicHigh_foldchange = pda.tm.e([  
            ("cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]),
            ("ct", "cp73"),
            ("st", "fc_medians")
        ])

cp73_chronicHigh_up = (cp_both_wide_info.select(
    lambda x: (cp_both_wide_info.ix[x, cn_cp73_chronicHigh_bh_ttest_pval] < 0.10)
    and cp_both_wide_info.ix[x, cn_cp73_chronicHigh_foldchange] >= table_fc_threshold
))

cp73_chronicHigh_down = (cp_both_wide_info.select(
    lambda x: (cp_both_wide_info.ix[x, cn_cp73_chronicHigh_bh_ttest_pval] < 0.10)
    and cp_both_wide_info.ix[x, cn_cp73_chronicHigh_foldchange] <= -table_fc_threshold
))[["symbol", cn_cp73_chronicHigh_bh_ttest_pval, cn_cp73_chronicHigh_foldchange]]

# %%
cp73_chronicHigh_down
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4038 entries, 1415682_at to 1460728_s_at
# Data columns (total 3 columns):
# symbol                                                                                                                              3799  non-null values
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]    4038  non-null values
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["st", "fc_medians"]]                                   4038  non-null values
# dtypes: float64(2), object(1)

# %%
[c for c in pda.tm.m([("cmp"), 
          ("st", "pval"), 
          ("mc", "bh"), 
          ("tt", "welch ttest")], cp_both_wide_info.columns)]
# Out:
# not an encoded tag list
# not an encoded tag list
# not an encoded tag list
# ['[["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, acuteHigh"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]',
#  '[["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]], ["ct", "cp101"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]']

# %%
patterns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45101 entries, 1415670_at to AFFX-TrpnX-M_at
# Data columns (total 10 columns):
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, chronicHigh"]             45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]             45101  non-null values
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# dtypes: bool(10)
# <class 'pandas.core.frame.DataFrame'>
# Index: 45101 entries, 1415670_at to AFFX-TrpnX-M_at
# Data columns (total 10 columns):
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, chronicHigh"]             45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]             45101  non-null values
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# dtypes: bool(10)

# %%
patterns.columns = [[pda.tm.e(val) for (t, val) in pda.tm.d( c ) if t == "cmp"][0] for c in patterns.columns]

# %%
patterns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45101 entries, 1415670_at to AFFX-TrpnX-M_at
# Data columns (total 10 columns):
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, chronicHigh"]             45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]             45101  non-null values
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# dtypes: bool(10)

# %%
patterns.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45101 entries, 1415670_at to AFFX-TrpnX-M_at
# Data columns (total 10 columns):
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, chronicHigh"]             45101  non-null values
# ["6-OHDA, acuteHigh", "6-OHDA, acuteSaline"]             45101  non-null values
# ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]    45101  non-null values
# ["6-OHDA, chronicLow", "6-OHDA, chronicSaline"]          45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]         45101  non-null values
# ["6-OHDA, chronicHigh", "6-OHDA, chronicLow"]            45101  non-null values
# dtypes: bool(10)

# %%
r =

# %%
def patternGroup(x):
    r = patterns.ix[ x, :]
    return int("".join([str(int(a)) for a in r]), 2)

# %%
g = patterns.groupby(patternGroup)

# %%
len(g.groups.items())
# Out:
# 231

# %%
for (k, v) in g.groups.items():
    print k, len(v)
# Out:
# 0 19529
# 512 78
# 2 88
# 4 7
# 6 1
# 8 22
# 10 5
# 514 5
# 16 1639
# 18 30
# 20 1
# 22 2
# 24 6
# 768 11
# 32 3406
# 688 25
# 34 34
# 36 1
# 38 1
# 40 3
# 42 1
# 690 5
# 48 2151
# 520 1
# 50 58
# 52 1
# 54 6
# 56 10
# 58 4
# 522 2
# 62 1
# 64 87
# 608 2
# 578 1
# 1008 37
# 70 1
# 72 1
# 866 1
# 80 19
# 440 24
# 88 1
# 90 1
# 954 2
# 96 25
# 528 15
# 98 1
# 992 19
# 444 1
# 618 1
# 786 1
# 624 1
# 986 1
# 114 1
# 754 2
# 720 5
# 128 2721
# 1010 8
# 642 3
# 132 1
# 136 9
# 138 2
# 962 1
# 656 13
# 146 9
# 150 2
# 152 4
# 666 1
# 704 2
# 282 1
# 160 1052
# 880 2
# 162 20
# 960 1
# 166 2
# 168 9
# 170 2
# 172 1
# 176 710
# 178 20
# 182 4
# 184 2
# 192 163
# 544 37
# 706 1
# 944 99
# 552 2
# 200 1
# 546 3
# 208 127
# 210 7
# 212 1
# 214 1
# 216 2
# 672 26
# 734 1
# 224 147
# 464 319
# 738 1
# 230 1
# 232 4
# 234 1
# 236 1
# 978 3
# 752 8
# 758 2
# 400 1800
# 246 1
# 760 3
# 250 1
# 530 1
# 298 1
# 946 12
# 256 1099
# 896 73
# 258 9
# 260 1
# 982 2
# 264 6
# 898 7
# 272 148
# 984 1
# 274 6
# 278 1
# 674 1
# 640 21
# 248 2
# 288 262
# 560 49
# 290 9
# 292 1
# 294 1
# 112 9
# 810 1
# 562 7
# 304 243
# 904 3
# 306 5
# 310 2
# 314 1
# 828 1
# 914 3
# 320 37
# 736 7
# 834 1
# 130 15
# 226 5
# 336 8
# 568 1
# 850 1
# 352 20
# 144 844
# 354 1
# 870 1
# 360 1
# 658 3
# 368 20
# 488 17
# 370 2
# 374 1
# 950 1
# 490 2
# 384 2129
# 832 1
# 386 54
# 388 3
# 406 5
# 390 1
# 392 9
# 394 3
# 912 60
# 920 1
# 402 46
# 404 6
# 918 2
# 408 11
# 410 7
# 922 1
# 928 113
# 240 124
# 930 11
# 420 2
# 422 8
# 424 27
# 426 6
# 242 8
# 432 1775
# 434 82
# 436 2
# 438 5
# 952 10
# 500 2
# 442 4
# 956 1
# 958 2
# 816 7
# 448 37
# 416 1876
# 450 3
# 1014 1
# 454 1
# 456 1
# 418 85
# 976 22
# 1016 12
# 466 21
# 468 1
# 470 5
# 472 4
# 474 6
# 1018 1
# 990 1
# 800 8
# 480 204
# 482 8
# 484 1
# 486 1
# 1000 5
# 1002 4
# 496 437
# 936 8
# 498 47
# 1012 2
# 1022 2
# 502 13
# 784 3
# 504 17
# 576 1
# 506 4
# 508 1
# 938 2
# 510 3

# %%
figsize(10,10)
imshow( g.get_group(656).as_matrix(), interpolation="nearest", cmap=get_cmap("gray"))

# %%
def uniqueSym(symbolSeries):
    symbolSeries = symbolSeries.fillna("-")
    r = set(symbolSeries)
    r.discard(nan)
    r.discard("-")
    return(r)

# %%
targets = cz.target.unique()
tfs = cz.tf.unique()

# %%
chea = pd.read_table("/data/adrian/Dropbox/Data/chea/chea-background.csv", header=None, 
                     names=["chea_id", "tf", "tf_pmid", "target", 
                            "pmid", "exp_type", "cell_type", "organism", "date"], sep=",")

# %%
chea = chea.astype('unicode')

# %%
czm = zeros( [len(targets), len(tfs)] )
target_index = dict( (a[1], a[0]) for a in enumerate(targets) )
tf_index = dict( (a[1], a[0]) for a in enumerate(tfs) )

# %%
pandasql.sqldf("select tf, count(*) c from cz group by tf order by c desc", locals())[0:10]

# %%
for i in cz.index:
    czm[target_index[cz.ix[i, "target"]], tf_index[cz.ix[i, "tf"]]] = 1

# %%
czm_df = pandas.DataFrame(data=czm, index=target_index, columns=tf_index)

# %%
import IPython

# %%
IPython.display.HTML( cz[0:5].to_html() )

# %%
cp73_dopamine_depletion_up
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 1438967_x_at to 1426734_at
# Data columns (total 5 columns):
# probe_id                                                                                                                                 88  non-null values
# symbol                                                                                                                                   88  non-null values
# gene_name                                                                                                                                88  non-null values
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]    92  non-null values
# [["cmp", ["6-OHDA, chronicSaline", "Ascorbate, chronicSaline"]], ["ct", "cp73"], ["st", "fc_medians"]]                                   92  non-null values
# dtypes: float64(2), object(3)

# %%
import itertools

# %%
177 * 177 * 177
# Out:
# 5545233

# %%
len( cz.groupby("target").groups.items() )
# Out:
# 1763

# %%
len(  list( itertools.combinations( cz.ix[g, "tf"].unique(), 3) ) )
# Out:
# 2925

# %%
def countTFcombos( genegroup, combination_size ):
    z = [a.upper() for a in set( uniqueSym( genegroup.symbol ))]
    z_set = set(z)
    cz= chea.select( lambda x: chea.ix[x, "target"] in z_set)
    
    print(len(cz.index))
    
    pair_counts = {}
    for (target_group, g) in cz.groupby("target").groups.items():
        group_tfs = cz.ix[g, "tf"].unique()
        group_tfs.sort()
#        for combo in itertools.combinations( group_tfs , combination_size):
#            pair_counts[combo] = pair_counts.setdefault(combo, 0) + 1
        for tf in group_tfs:
            pair_counts[tf] = pair_counts.setdefault(tf, 0) + 1
    result = pd.DataFrame( pair_counts.items(), columns=["tf", "count"]).sort_index(by="count", ascending=False) 
    result["total_genes_in_group"] = len(z)
    #ret
    return result

# %%
g
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2529 entries, 102 to 276607
# Data columns (total 6 columns):
# genename           2529  non-null values
# chrom              2529  non-null values
# motif_type         2529  non-null values
# motif_name         2529  non-null values
# max_motif_score    2529  non-null values
# motif_count        2529  non-null values
# dtypes: float64(1), int64(1), object(4)

# %%
def countMotifCombos( genegroup, combination_size ):
    z = [a for a in set( uniqueSym( genegroup.symbol ))]
    z_set = set(z)
    cz= mm9_gene_motifs.select( lambda x: mm9_gene_motifs.ix[x, "genename"] in z_set)
    
    print(len(cz.index))
    
    pair_counts = {}
    for (target_group, g) in cz.groupby("genename").groups.items():
        group_motifs = cz.ix[g, "motif_name"].unique()
        group_motifs.sort()
#        for combo in itertools.combinations( group_tfs , combination_size):
#            pair_counts[combo] = pair_counts.setdefault(combo, 0) + 1
        for motif_name in group_motifs:
            pair_counts[motif_name] = pair_counts.setdefault(motif_name, 0) + 1
    result = pd.DataFrame( pair_counts.items(), columns=["motif_name", "count"]).sort_index(by="count", ascending=False) 
    result["total_genes_in_group"] = len(z)
    #ret
    return result

# %%
def getMotifMatches( genegroup, combination_size ):
#    z = [a for a in set( uniqueSym( genegroup.symbol ))]
#    z_set = set(z)
    cz= mm9_gene_motifs.merge(genegroup, left_on="genename", right_on="symbol") 
    #select( lambda x: mm9_gene_motifs.ix[x, "genename"] in z_set)
    
    print(len(cz.index))
    
    result = []
    for k, z in cz.groupby("motif_name"):
        result.append( { "motif_name"  : k,
                        "
                         "motif_occurrences"
                        }  )
    
    
    for (target_group, g) in cz.groupby("genename").groups.items():
        group_motifs = cz.ix[g, "motif_name"].unique()
        group_motifs.sort()
#        for combo in itertools.combinations( group_tfs , combination_size):
#            pair_counts[combo] = pair_counts.setdefault(combo, 0) + 1
        for motif_name in group_motifs:
            pair_counts[motif_name] = pair_counts.setdefault(motif_name, 0) + 1
    result = pd.DataFrame( pair_counts.items(), columns=["motif_name", "count"]).sort_index(by="count", ascending=False) 
    result["total_genes_in_group"] = len(z)
    #ret
    return result

# %%
r, c = getMotifMatches( cp73_chronicHigh_down, 1)
# Out:
# 53342

# %%
c
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53342 entries, 0 to 53341
# Data columns (total 9 columns):
# genename                                                                                                                            53342  non-null values
# chrom                                                                                                                               53342  non-null values
# motif_type                                                                                                                          53342  non-null values
# motif_name                                                                                                                          53342  non-null values
# max_motif_score                                                                                                                     53342  non-null values
# motif_count                                                                                                                         53342  non-null values
# symbol                                                                                                                              53342  non-null values
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["mc", "bh"], ["st", "pval"], ["tt", "welch ttest"]]    53342  non-null values
# [["cmp", ["6-OHDA, chronicHigh", "6-OHDA, chronicSaline"]], ["ct", "cp73"], ["st", "fc_medians"]]                                   53342  non-null values
# dtypes: float64(3), int64(1), object(5)

# %%
IPython.display.HTML( c.sort_index(by=c.columns[8], ascending=False).to_html() )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-582-49a39dd90e1e> in <module>()
# ----> 1 IPython.display.HTML( c.sort_index(by=c.columns[8], ascending=False).to_html() )
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_html(self, buf, columns, col_space, colSpace, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, force_unicode, bold_rows, classes, escape)
#    1530                                            bold_rows=bold_rows,
#    1531                                            escape=escape)
# -> 1532         formatter.to_html(classes=classes)
#    1533
#    1534         if buf is None:
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in to_html(self, classes)
#     410         """
#     411         html_renderer = HTMLFormatter(self, classes=classes)
# --> 412         html_renderer.write_result(self.buf)
#     413
#     414     def _get_formatted_column_labels(self):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in write_result(self, buf)
#     589             indent += self.indent_delta
#     590             indent = self._write_header(indent)
# --> 591             indent = self._write_body(indent)
#     592
#     593         self.write('</table>', indent)
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in _write_body(self, indent)
#     682                 self._write_hierarchical_rows(fmt_values, indent)
#     683             else:
# --> 684                 self._write_regular_rows(fmt_values, indent)
#     685         else:
#     686             for i in range(len(self.frame)):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in _write_regular_rows(self, fmt_values, indent)
#     708             row.extend(fmt_values[j][i] for j in range(ncols))
#     709             self.write_tr(row, indent, self.indent_delta, tags=None,
# --> 710                           nindex_levels=1)
#     711
#     712     def _write_hierarchical_rows(self, fmt_values, indent):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in write_tr(self, line, indent, indent_delta, header, align, tags, nindex_levels)
#     558                 self.write_th(s, indent, tags=val_tag)
#     559             else:
# --> 560                 self.write_td(s, indent, tags=val_tag)
#     561
#     562         indent -= indent_delta
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in write_td(self, s, indent, tags)
#     523
#     524     def write_td(self, s, indent=0, tags=None):
# --> 525         return self._write_cell(s, kind='td', indent=indent, tags=tags)
#     526
#     527     def _write_cell(self, s, kind='td', indent=0, tags=None):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in _write_cell(self, s, kind, indent, tags)
#     540         rs = com.pprint_thing(s, escape_chars=esc)
#     541         self.write(
# --> 542             '%s%s</%s>' % (start_tag, rs, kind), indent)
#     543
#     544     def write_tr(self, line, indent=0, indent_delta=4, header=False,
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.pyc in write(self, s, indent)
#     510         self.escape = self.fmt.kwds.get('escape', True)
#     511
# --> 512     def write(self, s, indent=0):
#     513         rs = com.pprint_thing(s)
#     514         self.elements.append(' ' * indent + rs)
#
# KeyboardInterrupt:

# %%
for k, g in cz.groupby("tf"):
    print k, len(g.target.unique())
# Out:
# AHR 87
# AR 545
# ARNT 116
# ASH2L 394
# ATF3 268
# BACH1 121
# BCL11B 4
# BCL3 113
# BMI1 143
# BP1 3
# CCND1 247
# CDKN2AIP 21
# CDX2 81
# CEBPA 64
# CEBPB 204
# CEBPD 57
# CHD1 108
# CHD7 9
# CIITA 5
# CLOCK 86
# CNOT3 157
# CREB1 701
# CREM 868
# CRX 80
# CTCF 152
# CTNNB1 150
# CUX1 189
# DACH1 193
# DCP1A 94
# DMRT1 266
# DNAJC2 78
# DROSHA 36
# E2F1 612
# E2F4 371
# E2F7 9
# EBNA2 112
# EED 59
# EGR1 653
# EKLF 164
# ELF1 91
# ELF5 125
# ELK1 204
# EOMES 292
# EP300 248
# ERG 337
# ESR1 229
# ESR2 53
# ESRRB 155
# EST1 55
# ETS1 149
# ETS2 29
# EWS-ERG 83
# EWS-FLI1 49
# EZH2 123
# FLI1 725
# FOXA2 293
# FOXM1 31
# FOXO1 36
# FOXO3 312
# FOXP1 410
# FOXP2 214
# FOXP3 155
# GABP 322
# GATA1 436
# GATA2 431
# GATA3 89
# GATA4 203
# GBX2 25
# GFI1B 235
# GLI1 2
# HCFC1 23
# HIF1A 51
# HNF4A 625
# HOXA2 5
# HOXB4 201
# HOXD13 17
# HSF1 97
# HTT 30
# IKZF1 8
# IRF1 48
# IRF8 87
# JARID1A 217
# JARID2 169
# JUN 138
# KDM5B 426
# KDM6A 57
# KLF1 134
# KLF2 16
# KLF4 513
# KLF5 16
# LMO2 173
# LYL1 88
# MECOM 236
# MEF2A 94
# MEIS1 189
# MITF 578
# MTF2 327
# MYB 134
# MYBL1 18
# MYBL2 200
# MYC 860
# MYCN 295
# NACC1 77
# NANOG 641
# NFE2L2 174
# NKX2-5 145
# NOTCH1 39
# NR0B1 177
# NR1H3 76
# NR1I2 83
# NR3C1 201
# NR4A2 19
# NRF2 133
# OLIG2 227
# PADI4 112
# PAX3-FKHR 112
# PAX6 72
# PBX1 155
# PDX1 67
# PHC1 67
# PHF8 180
# POU3F2 140
# POU5F1 595
# PPARD 387
# PPARG 556
# PRDM14 228
# PRDM16 15
# PRDM5 110
# RAD21 181
# RARG 55
# RBPJ 160
# RCOR1 136
# RCOR2 44
# RCOR3 329
# REST 467
# RNF2 171
# RUNX1 761
# RUNX2 291
# SALL1 11
# SALL4 306
# SCL 191
# SETDB1 371
# SFPI1 328
# SIN3A 140
# SIN3B 454
# SMAD 12
# SMAD1 64
# SMAD2 230
# SMAD3 335
# SMAD4 464
# SMARCA4 375
# SOX11 94
# SOX17 183
# SOX2 778
# SOX9 5
# SPI1 780
# SREBP1 81
# SREBP2 109
# SRF 143
# SRY 13
# STAT1 37
# STAT3 617
# STAT4 171
# STAT5 118
# STAT6 47
# SUZ12 485
# TAF7L 97
# TAL1 462
# TBP 100
# TBX3 87
# TBX5 208
# TCF21 12
# TCF3 381
# TCF4 380
# TCF7 146
# TCF7L2 64
# TCFAP2C 291
# TCFCP2L1 220
# TEAD4 221
# TET1 405
# TFAP2A 168
# TFAP2C 122
# TFEB 96
# THAP11 72
# THRA 19
# TP53 540
# TP63 605
# TRIM28 429
# TRP63 20
# TTF2 203
# VDR 300
# WT1 260
# XRN2 178
# YAP1 263
# YY1 142
# ZFP281 238
# ZFP42 144
# ZFX 360
# ZIC3 42
# ZNF263 12
# ZNF274 17
# ZNF652 6

# %%
cz.groupby("motif_name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-560-67798268a3ef> in <module>()
# ----> 1 cz.groupby("motif_name")
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys)
#     151         axis = self._get_axis_number(axis)
#     152         return groupby(self, by, axis=axis, level=level, as_index=as_index,
# --> 153                        sort=sort, group_keys=group_keys)
#     154
#     155     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#     535         raise TypeError('invalid type: %s' % type(obj))
#     536
# --> 537     return klass(obj, by, **kwds)
#     538
#     539
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys)
#     193         if grouper is None:
#     194             grouper, exclusions = _get_grouper(obj, keys, axis=axis,
# --> 195                                                level=level, sort=sort)
#     196
#     197         self.grouper = grouper
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_grouper(obj, key, axis, level, sort)
#    1318             exclusions.append(gpr)
#    1319             name = gpr
# -> 1320             gpr = obj[gpr]
#    1321
#    1322         if (isinstance(gpr,Categorical) and len(gpr) != len(obj)):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1926         else:
#    1927             # get column
# -> 1928             return self._get_item_cache(key)
#    1929
#    1930     def _getitem_slice(self, key):
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#     568             return cache[item]
#     569         except Exception:
# --> 570             values = self._data.get(item)
#     571             res = self._box_item_values(item, values)
#     572             cache[item] = res
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    1381
#    1382     def get(self, item):
# -> 1383         _, block = self._find_block(item)
#    1384         return block.get(item)
#    1385
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _find_block(self, item)
#    1523
#    1524     def _find_block(self, item):
# -> 1525         self._check_have(item)
#    1526         for i, block in enumerate(self.blocks):
#    1527             if item in block:
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _check_have(self, item)
#    1530     def _check_have(self, item):
#    1531         if item not in self.items:
# -> 1532             raise KeyError('no item named %s' % com.pprint_thing(item))
#    1533
#    1534     def reindex_axis(self, new_axis, method=None, axis=0, copy=True):
#
# KeyError: u'no item named motif_name'

# %%
countMotifCombos( cp73_chronicHigh_up, 1)[0:20]
# Out:
# 29880
#                motif_name  count  total_genes_in_group
# 28                 SP1.p2   1333                  1871
# 1                 KLF4.p3   1192                  1871
# 55                 MAZ.p2   1176                  1871
# 143              PATZ1.p2   1127                  1871
# 17               TFDP1.p2    998                  1871
# 126         TFAP2{A,C}.p2    996                  1871
# 67                MZF1.p2    901                  1871
# 168             TFAP2B.p2    799                  1871
# 29               GTF2I.p2    744                  1871
# 148               PAX5.p2    732                  1871
# 68            ELF1,2,4.p2    689                  1871
# 120               SPI1.p2    614                  1871
# 57                HIC1.p2    585                  1871
# 94   ELK1,4_GABP{A,B1}.p3    584                  1871
# 154                YY1.p2    561                  1871
# 93             EGR1..3.p2    496                  1871
# 23               RREB1.p2    474                  1871
# 102                FEV.p2    458                  1871
# 105               MAFB.p2    456                  1871
# 82          TCF4_dimer.p2    454                  1871

# %%
test = countTFcombos( cp73_chronicHigh_up, 1)
# Out:
# 47501

# %%
test = pd.DataFrame( countTFcombos( cp73_chronicHigh_up, 1).items(), columns=["tf", "count"]).sort_index(by="count", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-416-9b1a8a1ebaee> in <module>()
# ----> 1 test = pd.DataFrame( countTFcombos( cp73_chronicHigh_up, 1).items(), columns=["tf", "count"]).sort_index(by="count", ascending=False)
#
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getattr__(self, name)
#    2005             return self[name]
#    2006         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2007                              (type(self).__name__, name))
#    2008
#    2009     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'items'
# 47501

# %%
test[0:10].merge(tf_target_counts, left_on="tf", right_index=True)[0:10]
# Out:
#         tf   tf_x  count  total_genes_in_group  chea_target_count   tf_y
# 93    CREM   CREM    868                  1871               5776   CREM
# 18     MYC    MYC    860                  1871               9863    MYC
# 75    SPI1   SPI1    780                  1871               8273   SPI1
# 152   SOX2   SOX2    778                  1871               9261   SOX2
# 38   RUNX1  RUNX1    761                  1871               7624  RUNX1
# 25    FLI1   FLI1    725                  1871               7063   FLI1
# 26   CREB1  CREB1    701                  1871               4907  CREB1
# 59    EGR1   EGR1    653                  1871               7207   EGR1
# 114  NANOG  NANOG    641                  1871               8386  NANOG
# 87   HNF4A  HNF4A    625                  1871               6749  HNF4A

# %%
test.merge(tf_target_counts, left_on="tf", right_index=True)[0:10]
# Out:
#          tf     tf_x  count  total_genes  chea_target_count     tf_y
# 13    CREB1    CREB1      9           10               4907    CREB1
# 54     CREM     CREM      8           10               5776     CREM
# 43     SPI1     SPI1      6           10               8273     SPI1
# 8       MYC      MYC      6           10               9863      MYC
# 12     FLI1     FLI1      6           10               7063     FLI1
# 23    KDM5B    KDM5B      5           10               3724    KDM5B
# 22    RUNX1    RUNX1      5           10               7624    RUNX1
# 84  SMARCA4  SMARCA4      5           10               3481  SMARCA4
# 47    PPARG    PPARG      5           10               4976    PPARG
# 44    NANOG    NANOG      4           10               8386    NANOG

# %%
len(z)
# Out:
# 1871

# %%
tf_target_counts = []
for (k, g) in chea.groupby("tf"):
    tf_target_counts.append( { "tf" : k, "chea_target_count" : len( uniqueSym( g.target )) } )
tf_target_counts = pd.DataFrame.from_dict(tf_target_counts)
tf_target_counts.index = tf_target_counts.tf

# %%
mm9_motif_gene_counts = []
for (k, g) in mm9_gene_motifs.groupby("motif_name"):
    mm9_motif_gene_counts.append( { "motif_name" : k, "motif_gene_count" : len(g.genename.unique()) } )
mm9_motif_gene_counts = pd.DataFrame.from_dict( mm9_motif_gene_counts )
mm9_motif_gene_counts.index = mm9_motif_gene_counts.motif_name

# %%
pd.set_printoptions(max_columns=100, max_rows=100)
# Out:
# /data/adrian/anaconda/lib/python2.7/site-packages/pandas/core/format.py:1612: FutureWarning: set_printoptions is deprecated, use set_option instead
#   FutureWarning)

# %%
IPython.display.HTML( mm9_motif_gene_counts.sort_index(by="motif_gene_count", ascending=False).to_html() )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>motif_gene_count</th>
#       <th>motif_name</th>
#     </tr>
#     <tr>
#       <th>motif_name</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SP1.p2</th>
#       <td> 12044</td>
#       <td>                            SP1.p2</td>
#     </tr>
#     <tr>
#       <th>KLF4.p3</th>
#       <td> 10899</td>
#       <td>                           KLF4.p3</td>
#     </tr>
#     <tr>
#       <th>MAZ.p2</th>
#       <td> 10878</td>
#       <td>                            MAZ.p2</td>
#     </tr>
#     <tr>
#       <th>PATZ1.p2</th>
#       <td> 10334</td>
#       <td>                          PATZ1.p2</td>
#     </tr>
#     <tr>
#       <th>MZF1.p2</th>
#       <td>  8515</td>
#       <td>                           MZF1.p2</td>
#     </tr>
#     <tr>
#       <th>TFAP2{A,C}.p2</th>
#       <td>  8076</td>
#       <td>                     TFAP2{A,C}.p2</td>
#     </tr>
#     <tr>
#       <th>TFDP1.p2</th>
#       <td>  8067</td>
#       <td>                          TFDP1.p2</td>
#     </tr>
#     <tr>
#       <th>GTF2I.p2</th>
#       <td>  6874</td>
#       <td>                          GTF2I.p2</td>
#     </tr>
#     <tr>
#       <th>TFAP2B.p2</th>
#       <td>  6217</td>
#       <td>                         TFAP2B.p2</td>
#     </tr>
#     <tr>
#       <th>PAX5.p2</th>
#       <td>  5810</td>
#       <td>                           PAX5.p2</td>
#     </tr>
#     <tr>
#       <th>ELF1,2,4.p2</th>
#       <td>  5707</td>
#       <td>                       ELF1,2,4.p2</td>
#     </tr>
#     <tr>
#       <th>SPI1.p2</th>
#       <td>  5555</td>
#       <td>                           SPI1.p2</td>
#     </tr>
#     <tr>
#       <th>YY1.p2</th>
#       <td>  5456</td>
#       <td>                            YY1.p2</td>
#     </tr>
#     <tr>
#       <th>TCF4_dimer.p2</th>
#       <td>  4716</td>
#       <td>                     TCF4_dimer.p2</td>
#     </tr>
#     <tr>
#       <th>RREB1.p2</th>
#       <td>  4649</td>
#       <td>                          RREB1.p2</td>
#     </tr>
#     <tr>
#       <th>ELK1,4_GABP{A,B1}.p3</th>
#       <td>  4645</td>
#       <td>              ELK1,4_GABP{A,B1}.p3</td>
#     </tr>
#     <tr>
#       <th>HIC1.p2</th>
#       <td>  4518</td>
#       <td>                           HIC1.p2</td>
#     </tr>
#     <tr>
#       <th>HOX{A6,A7,B6,B7}.p2</th>
#       <td>  4193</td>
#       <td>               HOX{A6,A7,B6,B7}.p2</td>
#     </tr>
#     <tr>
#       <th>FEV.p2</th>
#       <td>  4192</td>
#       <td>                            FEV.p2</td>
#     </tr>
#     <tr>
#       <th>BPTF.p2</th>
#       <td>  4175</td>
#       <td>                           BPTF.p2</td>
#     </tr>
#     <tr>
#       <th>SPIB.p2</th>
#       <td>  3935</td>
#       <td>                           SPIB.p2</td>
#     </tr>
#     <tr>
#       <th>SNAI1..3.p2</th>
#       <td>  3921</td>
#       <td>                       SNAI1..3.p2</td>
#     </tr>
#     <tr>
#       <th>EGR1..3.p2</th>
#       <td>  3885</td>
#       <td>                        EGR1..3.p2</td>
#     </tr>
#     <tr>
#       <th>FOXD3.p2</th>
#       <td>  3629</td>
#       <td>                          FOXD3.p2</td>
#     </tr>
#     <tr>
#       <th>MAFB.p2</th>
#       <td>  3359</td>
#       <td>                           MAFB.p2</td>
#     </tr>
#     <tr>
#       <th>ZFP161.p2</th>
#       <td>  3321</td>
#       <td>                         ZFP161.p2</td>
#     </tr>
#     <tr>
#       <th>GATA1..3.p2</th>
#       <td>  3297</td>
#       <td>                       GATA1..3.p2</td>
#     </tr>
#     <tr>
#       <th>MTF1.p2</th>
#       <td>  3146</td>
#       <td>                           MTF1.p2</td>
#     </tr>
#     <tr>
#       <th>EHF.p2</th>
#       <td>  3024</td>
#       <td>                            EHF.p2</td>
#     </tr>
#     <tr>
#       <th>NRF1.p2</th>
#       <td>  3000</td>
#       <td>                           NRF1.p2</td>
#     </tr>
#     <tr>
#       <th>ZNF148.p2</th>
#       <td>  2982</td>
#       <td>                         ZNF148.p2</td>
#     </tr>
#     <tr>
#       <th>PRRX1,2.p2</th>
#       <td>  2894</td>
#       <td>                        PRRX1,2.p2</td>
#     </tr>
#     <tr>
#       <th>NHLH1,2.p2</th>
#       <td>  2886</td>
#       <td>                        NHLH1,2.p2</td>
#     </tr>
#     <tr>
#       <th>NFY{A,B,C}.p2</th>
#       <td>  2875</td>
#       <td>                     NFY{A,B,C}.p2</td>
#     </tr>
#     <tr>
#       <th>FOX{I1,J2}.p2</th>
#       <td>  2722</td>
#       <td>                     FOX{I1,J2}.p2</td>
#     </tr>
#     <tr>
#       <th>MYFfamily.p2</th>
#       <td>  2672</td>
#       <td>                      MYFfamily.p2</td>
#     </tr>
#     <tr>
#       <th>bHLH_family.p2</th>
#       <td>  2529</td>
#       <td>                    bHLH_family.p2</td>
#     </tr>
#     <tr>
#       <th>ETS1,2.p2</th>
#       <td>  2463</td>
#       <td>                         ETS1,2.p2</td>
#     </tr>
#     <tr>
#       <th>KLF12.p2</th>
#       <td>  2342</td>
#       <td>                          KLF12.p2</td>
#     </tr>
#     <tr>
#       <th>NFE2L1.p2</th>
#       <td>  2329</td>
#       <td>                         NFE2L1.p2</td>
#     </tr>
#     <tr>
#       <th>ZEB1.p2</th>
#       <td>  2274</td>
#       <td>                           ZEB1.p2</td>
#     </tr>
#     <tr>
#       <th>AHR_ARNT_ARNT2.p2</th>
#       <td>  1983</td>
#       <td>                 AHR_ARNT_ARNT2.p2</td>
#     </tr>
#     <tr>
#       <th>ATF5_CREB3.p2</th>
#       <td>  1951</td>
#       <td>                     ATF5_CREB3.p2</td>
#     </tr>
#     <tr>
#       <th>GFI1.p2</th>
#       <td>  1832</td>
#       <td>                           GFI1.p2</td>
#     </tr>
#     <tr>
#       <th>TFCP2.p2</th>
#       <td>  1777</td>
#       <td>                          TFCP2.p2</td>
#     </tr>
#     <tr>
#       <th>CDX1,2,4.p2</th>
#       <td>  1764</td>
#       <td>                       CDX1,2,4.p2</td>
#     </tr>
#     <tr>
#       <th>SPZ1.p2</th>
#       <td>  1750</td>
#       <td>                           SPZ1.p2</td>
#     </tr>
#     <tr>
#       <th>LMO2.p2</th>
#       <td>  1701</td>
#       <td>                           LMO2.p2</td>
#     </tr>
#     <tr>
#       <th>HBP1_HMGB_SSRP1_UBTF.p2</th>
#       <td>  1696</td>
#       <td>           HBP1_HMGB_SSRP1_UBTF.p2</td>
#     </tr>
#     <tr>
#       <th>PAX2.p2</th>
#       <td>  1690</td>
#       <td>                           PAX2.p2</td>
#     </tr>
#     <tr>
#       <th>ZNF143.p2</th>
#       <td>  1642</td>
#       <td>                         ZNF143.p2</td>
#     </tr>
#     <tr>
#       <th>EP300.p2</th>
#       <td>  1508</td>
#       <td>                          EP300.p2</td>
#     </tr>
#     <tr>
#       <th>NR5A1,2.p2</th>
#       <td>  1493</td>
#       <td>                        NR5A1,2.p2</td>
#     </tr>
#     <tr>
#       <th>STAT2,4,6.p2</th>
#       <td>  1484</td>
#       <td>                      STAT2,4,6.p2</td>
#     </tr>
#     <tr>
#       <th>SOX17.p2</th>
#       <td>  1483</td>
#       <td>                          SOX17.p2</td>
#     </tr>
#     <tr>
#       <th>JUN.p2</th>
#       <td>  1473</td>
#       <td>                            JUN.p2</td>
#     </tr>
#     <tr>
#       <th>ZBTB16.p2</th>
#       <td>  1466</td>
#       <td>                         ZBTB16.p2</td>
#     </tr>
#     <tr>
#       <th>HES1.p2</th>
#       <td>  1458</td>
#       <td>                           HES1.p2</td>
#     </tr>
#     <tr>
#       <th>SOX2.p2</th>
#       <td>  1378</td>
#       <td>                           SOX2.p2</td>
#     </tr>
#     <tr>
#       <th>ARNT_ARNT2_BHLHB2_MAX_MYC_USF1.p2</th>
#       <td>  1356</td>
#       <td> ARNT_ARNT2_BHLHB2_MAX_MYC_USF1.p2</td>
#     </tr>
#     <tr>
#       <th>MYOD1.p2</th>
#       <td>  1312</td>
#       <td>                          MYOD1.p2</td>
#     </tr>
#     <tr>
#       <th>IKZF2.p2</th>
#       <td>  1230</td>
#       <td>                          IKZF2.p2</td>
#     </tr>
#     <tr>
#       <th>SREBF1,2.p2</th>
#       <td>  1184</td>
#       <td>                       SREBF1,2.p2</td>
#     </tr>
#     <tr>
#       <th>CREB1.p2</th>
#       <td>  1125</td>
#       <td>                          CREB1.p2</td>
#     </tr>
#     <tr>
#       <th>SOX{8,9,10}.p2</th>
#       <td>  1077</td>
#       <td>                    SOX{8,9,10}.p2</td>
#     </tr>
#     <tr>
#       <th>HNF4A_NR2F1,2.p2</th>
#       <td>  1072</td>
#       <td>                  HNF4A_NR2F1,2.p2</td>
#     </tr>
#     <tr>
#       <th>

# %%
tf_target_counts.ix["CREM", :]
# Out:
# chea_target_count    5776
# tf                   CREM
# Name: CREM, dtype: object

# %%
chea.target.unique()[3000:3500]
# Out:
# array([u'SLC35A2', u'SLC35C2', u'SLC37A2', u'SLC37A4', u'SLC38A1',
#        u'SLC38A2', u'SLC38A5', u'SLC3A2', u'SLC41A2', u'SLC43A1',
#        u'SLC6A13', u'SLC6A14', u'SLC6A4', u'SLC6A5', u'SLC7A8', u'SLC8A3',
#        u'SLC9A6', u'SLITRK4', u'SLITRK5', u'SMAD4', u'SMAD9', u'SMARCD2',
#        u'SMC1L1', u'SMOX', u'SMPD3', u'SMPX', u'SMS', u'SMTN', u'SNAP25',
#        u'SNAP29', u'SNAPC1', u'SNF1LK2', u'SNRP70', u'SNRPF', u'SNRPN',
#        u'SNW1', u'SNX12', u'SNX19', u'SOX5', u'SP1', u'SPAG7', u'SPAG9',
#        u'SPATA13', u'SPATA20', u'SPG7', u'SPIRE1', u'SPRY3', u'SPTLC2',
#        u'SQRDL', u'SRP14', u'SRPR', u'SRXN1', u'SSH1', u'SSH2', u'SSRP1',
#        u'ST5', u'ST8SIA2', u'STAB2', u'STAC3', u'STARD13', u'STARD5',
#        u'STARD6', u'STAT2', u'STK24', u'STK33', u'STK6', u'STRA13',
#        u'STRN4', u'STX10', u'STX16', u'STX5A', u'SUHW2', u'SULF2',
#        u'SUPT4H1', u'SUZ12P', u'SV2B', u'SYBL1', u'SYCP2', u'SYNE2',
#        u'SYNJ1', u'SYT13', u'SYT16', u'SYTL2', u'SYTL4', u'TAF1', u'TAF10',
#        u'TANC2', u'TAOK2', u'TARSL2', u'TBC1D15', u'TBC1D21', u'TBCD',
#        u'TBX3', u'TBX5', u'TCEAL1', u'TCEAL8', u'TCF15', u'TCF2', u'TCF20',
#        u'TCL1B', u'TDG', u'TDRD9', u'TEAD2', u'TEAD4', u'TEKT3', u'TEP1',
#        u'TEX101', u'TEX2', u'TEX9', u'TGFB3', u'TGIF', u'TGM1', u'TGM2',
#        u'TGM3', u'TGM5', u'TGM7', u'THAP10', u'THBS1', u'THRAP5', u'TIAF1',
#        u'TIAM1', u'TIMELESS', u'TIMM17B', u'TIMM22', u'TIMM8B', u'TIMM9',
#        u'TINF2', u'TK1', u'TK2', u'TLCD1', u'TLR7', u'TM7SF3', u'TM9SF1',
#        u'TM9SF2', u'TMC3', u'TMCC3', u'TMCO5', u'TMED8', u'TMEM100',
#        u'TMEM102', u'TMEM107', u'TMEM16H', u'TMEM29', u'TMEM31', u'TMEM5',
#        u'TMEM83', u'TMEM88', u'TMEM9B', u'TMPRSS3', u'TMSL8', u'TNFRSF19',
#        u'TNFRSF1A', u'TNPO2', u'TNRC6C', u'TNRC9', u'TOB1', u'TOP3A',
#        u'TP53', u'TPM1', u'TPP2', u'TRA1', u'TRA@', u'TRAPPC2',
#        u'TRAPPC6A', u'TRAV20', u'TRHDE', u'TRIM3', u'TRIM37', u'TRIM68',
#        u'TRIP11', u'TRMT5', u'TRO', u'TRPC4', u'TRPC5', u'TRPM1', u'TRPM7',
#        u'TSC22D1', u'TSFM', u'TSG101', u'TSHR', u'TSPAN3', u'TSPYL2',
#        u'TSR1', u'TSSC4', u'TSSK4', u'TTC17', u'TTC23', u'TUB', u'TUBA8',
#        u'TUBGCP5', u'TUBGCP6', u'TUFM', u'TULP3', u'TXN2', u'TXNDC13',
#        u'TXNDC2', u'TXNL4B', u'TXNRD1', u'U2AF1L2', u'U2AF1L4', u'UACA',
#        u'UBB', u'UBC', u'UBE1', u'UBE2C', u'UBE2E4P', u'UBE2S', u'UBE2Z',
#        u'UBL3', u'UBL7', u'UCHL3', u'UFD1L', u'UGCGL2', u'UMOD', u'UMODL1',
#        u'UPF3B', u'UQCRC2', u'USH1C', u'USP12', u'USP14', u'USP18',
#        u'USP30', u'USP31', u'USP36', u'USP43', u'USP51', u'USP52',
#        u'USPL1', u'UTX', u'UXT', u'VAPA', u'VDR', u'VKORC1', u'VPS29',
#        u'VRK1', u'VRK3', u'VSIG1', u'VSIG2', u'VSIG4', u'VWF', u'WARS',
#        u'WBP11', u'WDR22', u'WDR44', u'WDR59', u'WDR68', u'WFDC6', u'WIBG',
#        u'WIPI1', u'WNK1', u'WNK3', u'WNT11', u'WNT5B', u'WSB2', u'WWOX',
#        u'WWP2', u'XBP1', u'XLKD1', u'XRCC1', u'XRN2', u'XRRA1', u'YES1',
#        u'YJDC', u'YLPM1', u'YWHAH', u'YY2', u'ZADH1', u'ZC3H12C',
#        u'ZCCHC14', u'ZCCHC2', u'ZDHHC13', u'ZFHX2', u'ZFP1', u'ZFP36L1',
#        u'ZIM2', u'ZMAT1', u'ZMAT5', u'ZMYM3', u'ZNF132', u'ZNF133',
#        u'ZNF135', u'ZNF140', u'ZNF154', u'ZNF175', u'ZNF18', u'ZNF180',
#        u'ZNF185', u'ZNF19', u'ZNF20', u'ZNF21', u'ZNF215', u'ZNF218',
#        u'ZNF224', u'ZNF226', u'ZNF227', u'ZNF23', u'ZNF236', u'ZNF24',
#        u'ZNF264', u'ZNF28', u'ZNF287', u'ZNF331', u'ZNF334', u'ZNF335',
#        u'ZNF341', u'ZNF345', u'ZNF384', u'ZNF397', u'ZNF41', u'ZNF417',
#        u'ZNF420', u'ZNF423', u'ZNF45', u'ZNF516', u'ZNF521', u'ZNF527',
#        u'ZNF528', u'ZNF530', u'ZNF537', u'ZNF548', u'ZNF551', u'ZNF553',
#        u'ZNF558', u'ZNF567', u'ZNF569', u'ZNF574', u'ZNF577', u'ZNF585A',
#        u'ZNF587', u'ZNF609', u'ZNF610', u'ZNF645', u'ZNF667', u'ZNF668',
#        u'ZNF673', u'ZNF690', u'ZNF75', u'ZNF81', u'ZNF83', u'ZNFN1A4',
#        u'ZNRF3', u'ZSCAN2', u'ZSCAN5', u'ZZEF1', u'1110019L22RIK',
#        u'1190017O12RIK', u'1200009O22RIK', u'1300013J15RIK',
#        u'1300014I06RIK', u'1600015H20RIK', u'1810031K17RIK',
#        u'2010001J22RIK', u'2010012C16RIK', u'2310015N21RIK',
#        u'2310045A20RIK', u'2410080H04RIK', u'2600010E01RIK',
#        u'2610017I09RIK', u'2610024A01RIK', u'2810022L02RIK',
#        u'2810451A06RIK', u'2900005J15RIK', u'2900093B09RIK',
#        u'3732412D22RIK', u'4631426J05RIK', u'4732486J07RIK',
#        u'4831416G18RIK', u'4921515A04RIK', u'4930447C04RIK',
#        u'4930511M11RIK', u'4930577M16RIK', u'4931406I20RIK',
#        u'4933407N01RIK', u'4933408F15', u'4933436C20RIK', u'5330439J01RIK',
#        u'5730446D14RIK', u'5730467H21RIK', u'5730596B20RIK', u'6030405A18',
#        u'6330514A18RIK', u'6332401O19RIK', u'6530402A20', u'9030611O19RIK',
#        u'9030612E09RIK', u'9030623N16RIK', u'9130213B05RIK', u'9430022A14',
#        u'9430023B20RIK', u'9430076C15RIK', u'9430077A04RIK',
#        u'9530027K23RIK', u'9930014A18RIK', u'A030009H04RIK',
#        u'A330008L17RIK', u'A630014H24RIK', u'A830053O21RIK',
#        u'A930008A22RIK', u'A930008G19RIK', u'A930038C07RIK',
#        u'A930040G15RIK', u'A930041G11RIK', u'AB041550', u'ABCA5', u'ABCF2',
#        u'ABHD3', u'ADAMTS8', u'ADCY8', u'ADCYAP1R1', u'ADH7', u'ADM',
#        u'ADRA1A', u'ADRA1D', u'ADRA2B', u'ADRB1', u'AI314180', u'AI849156',
#        u'AKT1S1', u'ALDH1A2', u'ALX3', u'AR', u'ARG2', u'ASB13', u'ASB3',
#        u'ASTN2', u'ATF3', u'ATOH1', u'ATOH8', u'ATP7B', u'AVPR1A',
#        u'AW125753', u'AW539457', u'B130055L09RIK', u'B230343H07RIK',
#        u'B230380D07RIK', u'B3GAT2', u'B830017H08RIK', u'BACH2', u'BARHL1',
#        u'BARX1', u'BARX2', u'BC014699', u'BC034054', u'BC038286',
#        u'BC055811', u'BC061194', u'BCAN', u'BCAS2', u'BCL2L11', u'BCL6B',
#        u'BHLHB3', u'BHLHB4', u'BHLHB8', u'BMP3', u'BMP6', u'BMP7',
#        u'BMP8A', u'BOC', u'BRUNOL4', u'C530028O21RIK', u'CACNA1E',
#        u'CACNG4', u'CALCA', u'CALN1', u'CAMK1D', u'CAMKK1', u'CAR10',
#        u'CAR11', u'CAR4', u'CARD10', u'CBLN2', u'CBLN4', u'CBX4', u'CCKBR',
#        u'CCND2', u'CCR9', u'CD14', u'CD200R3', u'CD24A', u'CDGAP',
#        u'CDH11', u'CDH22', u'CDH4', u'CDH8', u'CDK5R2', u'CDKN1C',
#        u'CDKN2A', u'CDKN2C', u'CDX2', u'CEBPA', u'CH25H', u'CHRD',
#        u'CHST11', u'CHST7', u'CHX10', u'CLDN23', u'CLSTN1', u'CNKSR2',
#        u'CNR1', u'CNTFR'], dtype=object)

# %%
len( chea.target.unique() )
# Out:
# 47510

# %%
len( chea.select(lambda x: chea.ix[x, "tf"] == "CREM").target.unique() )
# Out:
# 5776

# %%
len( uniqueSym( cp73_chronicHigh_up.symbol ))
# Out:
# 1871

# %%
test[0:50]
# Out:
#              tf  count
# 189     (CREM,)    868
# 24       (MYC,)    860
# 180     (SPI1,)    780
# 54      (SOX2,)    778
# 185    (RUNX1,)    761
# 51      (FLI1,)    725
# 111    (CREB1,)    701
# 19      (EGR1,)    653
# 4      (NANOG,)    641
# 172    (HNF4A,)    625
# 31     (STAT3,)    617
# 135     (E2F1,)    612
# 177     (TP63,)    605
# 95    (POU5F1,)    595
# 163     (MITF,)    578
# 127    (PPARG,)    556
# 68        (AR,)    545
# 181     (TP53,)    540
# 60      (KLF4,)    513
# 192    (SUZ12,)    485
# 159     (REST,)    467
# 131    (SMAD4,)    464
# 169     (TAL1,)    462
# 129    (SIN3B,)    454
# 120    (GATA1,)    436
# 35     (GATA2,)    431
# 63    (TRIM28,)    429
# 48     (KDM5B,)    426
# 171    (FOXP1,)    410
# 46      (TET1,)    405
# 123    (ASH2L,)    394
# 150    (PPARD,)    387
# 66      (TCF3,)    381
# 144     (TCF4,)    380
# 165  (SMARCA4,)    375
# 101   (SETDB1,)    371
# 47      (E2F4,)    371
# 118      (ZFX,)    360
# 151      (ERG,)    337
# 113    (SMAD3,)    335
# 121    (RCOR3,)    329
# 146    (SFPI1,)    328
# 90      (MTF2,)    327
# 21      (GABP,)    322
# 65     (FOXO3,)    312
# 67     (SALL4,)    306
# 1        (VDR,)    300
# 178     (MYCN,)    295
# 116    (FOXA2,)    293
# 28     (EOMES,)    292

# %%
down_2 = pd.DataFrame( countTFcombos(cp73_chronicHigh_down).items(), 
             columns=["pair", "c"] ).sort_index(by="c", ascending=False)
# Out:
# 61562

# %%
up_2 = pd.DataFrame( countTFcombos(cp73_chronicHigh_up).items(), 
             columns=["pair", "c"] ).sort_index(by="c", ascending=False)
# Out:
# 47501

# %%
down_2["frac"] = down_2["c"] / float(len(cp73_chronicHigh_down.index))

# %%
up_2["frac"] = up_2["c"] / float(len(cp73_chronicHigh_up.index))

# %%
both_3 = up_3.merge(down_3, left_on="pair", right_on="pair", how="outer", suffixes=("_up","_down")).fillna(0)

# %%
both_2 = up_2.merge(down_2, left_on="pair", right_on="pair", how="outer", suffixes=("_up","_down")).fillna(0)

# %%
both_3["diff"] = both_3["frac_up"] - both_3["frac_down"]

# %%
both_2["diff"] = both_2["frac_up"] - both_2["frac_down"]

# %%
both_2.sort_index(by="diff", ascending=False)[0:20]
# Out:
#                 pair  c_up   frac_up  c_down  frac_down      diff
# 0      (CREB1, CREM)   543  0.185641     395   0.097821  0.087820
# 5       (CREB1, MYC)   429  0.146667     358   0.088658  0.058009
# 8       (CREM, FLI1)   424  0.144957     374   0.092620  0.052337
# 25    (CREB1, RUNX1)   373  0.127521     307   0.076028  0.051494
# 27     (CREB1, FLI1)   365  0.124786     301   0.074542  0.050244
# 78      (CREM, TAL1)   293  0.100171     216   0.053492  0.046679
# 1        (CREM, MYC)   525  0.179487     537   0.132987  0.046501
# 22     (CREB1, SPI1)   376  0.128547     337   0.083457  0.045090
# 164    (CREB1, TAL1)   240  0.082051     163   0.040367  0.041685
# 42      (CREM, KLF4)   328  0.112137     285   0.070579  0.041557
# 106   (CREB1, PPARG)   272  0.092991     209   0.051758  0.041233
# 4       (CREM, SPI1)   439  0.150085     442   0.109460  0.040625
# 134    (CREB1, KLF4)   258  0.088205     193   0.047796  0.040409
# 6      (CREM, RUNX1)   426  0.145641     427   0.105745  0.039896
# 41     (CREB1, SOX2)   329  0.112479     298   0.073799  0.038680
# 88    (CREB1, NANOG)   286  0.097778     243   0.060178  0.037599
# 53     (CREM, PPARG)   317  0.108376     289   0.071570  0.036806
# 308  (CREB1, TRIM28)   197  0.067350     124   0.030708  0.036642
# 98   (CREB1, POU5F1)   280  0.095726     239   0.059188  0.036539
# 71     (CREB1, E2F1)   298  0.101880     264   0.065379  0.036501

# %%
both_3.sort_index(by="diff", ascending=True)[0:20]
# Out:
#                          pair  c_up   frac_up  c_down  frac_down      diff
# 454         (AR, HNF4A, SOX2)   151  0.051624     272   0.067360 -0.015736
# 3698    (FOXA2, POU5F1, SOX2)    86  0.029402     181   0.044824 -0.015422
# 3288       (FOXA2, MYC, SOX2)    90  0.030769     184   0.045567 -0.014798
# 1582     (GATA1, HNF4A, SOX2)   111  0.037949     212   0.052501 -0.014553
# 7128     (FOXA2, MYC, POU5F1)    68  0.023248     152   0.037642 -0.014395
# 4333        (AR, EGR1, SUZ12)    82  0.028034     171   0.042348 -0.014314
# 717      (FOXA2, HNF4A, SOX2)   135  0.046154     244   0.060426 -0.014272
# 15597    (AR, SMARCA4, SUZ12)    49  0.016752     125   0.030956 -0.014204
# 6135        (AR, FOXA2, MITF)    72  0.024615     154   0.038138 -0.013522
# 3403   (FOXA2, HNF4A, POU5F1)    89  0.030427     177   0.043834 -0.013406
# 345      (HNF4A, MYC, POU5F1)   160  0.054701     275   0.068103 -0.013402
# 32019      (AR, OLIG2, SUZ12)    34  0.011624     101   0.025012 -0.013388
# 10621    (AR, OLIG2, SMARCA4)    58  0.019829     134   0.033185 -0.013356
# 1328      (FOXA2, HNF4A, MYC)   116  0.039658     214   0.052997 -0.013338
# 3271       (AR, STAT3, SUZ12)    90  0.030769     178   0.044081 -0.013312
# 6929      (E2F4, HNF4A, SOX2)    69  0.023590     149   0.036899 -0.013310
# 1524      (HNF4A, SOX2, TCF4)   112  0.038291     208   0.051511 -0.013220
# 2794     (FOXA2, NANOG, SOX2)    94  0.032137     183   0.045319 -0.013183
# 2969        (AR, FOXA2, SOX2)    92  0.031453     180   0.044577 -0.013124
# 4240     (FOXA2, SOX2, STAT3)    82  0.028034     165   0.040862 -0.012828

# %%
pd.DataFrame( pair_counts.items(), columns=["pair", "c"] ).sort_index(by="c", ascending=False)[0:20]
# Out:
#                                   pair    c
# 2488849       (CREB1, CREM, MYC, SPI1)  211
# 3803349       (CREB1, CREM, FLI1, MYC)  204
# 16294561    (MYC, NANOG, POU5F1, SOX2)  200
# 5217325       (CREB1, CREM, E2F1, MYC)  190
# 11050087   (NANOG, POU5F1, SOX2, TCF3)  187
# 12708301     (CREB1, CREM, MYC, RUNX1)  186
# 7282345      (CREB1, CREM, FLI1, SPI1)  185
# 4381082        (CREM, FLI1, MYC, SPI1)  179
# 18644028    (CREB1, CREM, FLI1, RUNX1)  179
# 10696485    (CREB1, CREM, RUNX1, SPI1)  176
# 5156839       (CREB1, CREM, MYC, SOX2)  171
# 7336689   (NANOG, POU5F1, RUNX1, SOX2)  170
# 127909       (CREB1, CREM, MYC, NANOG)  170
# 19162240     (CREB1, CREM, HNF4A, MYC)  168
# 11540489       (CREM, E2F1, MYC, SPI1)  164
# 10903125      (CREB1, CREM, KLF4, MYC)  163
# 12612862      (CREM, FLI1, MYC, RUNX1)  163
# 2798627    (CREM, NANOG, POU5F1, SOX2)  161
# 10484106  (NANOG, POU5F1, SOX2, STAT3)  161
# 6263013       (CREB1, FLI1, MYC, SPI1)  160

# %%
pair_counts.items()

# %%
len( list( itertools.combinations( cz.tf.unique(), 2) ) )
# Out:
# 15576

# %%
cz.groupby("tf").count().sort_index(by="chea_id", ascending=False)[0:20]
# Out:
#         chea_id  tf  tf_pmid  target  pmid  exp_type  cell_type  organism  date
# tf
# SUZ12        72  72       72      72    72        72         72        72    72
# SOX2         44  44       44      44    44        44         44        44    44
# MYC          43  43       43      43    43        43         43        43    43
# POU5F1       38  38       38      38    38        38         38        38    38
# REST         38  38       38      38    38        38         38        38    38
# TP63         34  34       34      34    34        34         34        34    34
# TP53         32  32       32      32    32        32         32        32    32
# SPI1         31  31       31      31    31        31         31        31    31
# AR           30  30       30      30    30        30         30        30    30
# RUNX1        30  30       30      30    30        30         30        30    30
# NANOG        28  28       28      28    28        28         28        28    28
# HNF4A        28  28       28      28    28        28         28        28    28
# E2F1         25  25       25      25    25        25         25        25    25
# EGR1         25  25       25      25    25        25         25        25    25
# MTF2         23  23       23      23    23        23         23        23    23
# STAT3        22  22       22      22    22        22         22        22    22
# GATA2        21  21       21      21    21        21         21        21    21
# CREB1        20  20       20      20    20        20         20        20    20
# TCF3         19  19       19      19    19        19         19        19    19
# CREM         19  19       19      19    19        19         19        19    19

# %%
alib.plots.clusterHeatmap( czm_df, "", None, None, 
                            cluster_columns=True, 
                            cluster_rows=True, 
                            distmethod='jaccard')
