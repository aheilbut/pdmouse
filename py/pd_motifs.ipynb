# %%
import pandas as pd
import urllib2
import IPython
# Out:
# /data/adrian/anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from /data/adrian/anaconda/lib/python2.7/argparse.pyc, but /data/adrian/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
mm9_refFlat = pd.read_table("/data/adrian/Dropbox/Data/mouse_genome/refFlat.txt", 
                            names=["geneName", "name", "chrom", "strand", "txStart", 
                                     "txEnd", "cdsStart", "cdsEnd", "exonCount", "exonStarts", "exonEnds"],
                            sep="\t")

# %%
mm9_refFlat[0:10]["txEnd"] - mm9_refFlat[0:10]["txStart"]
# Out:
# 0     19301
# 1    135461
# 2     11597
# 3     12529
# 4     44771
# 5       924
# 6     14499
# 7     45293
# 8     97104
# 9      3170
# dtype: int64

# %%
IPython.display.HTML( mm9_refFlat[0:10].to_html() )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>geneName</th>
#       <th>name</th>
#       <th>chrom</th>
#       <th>strand</th>
#       <th>txStart</th>
#       <th>txEnd</th>
#       <th>cdsStart</th>
#       <th>cdsEnd</th>
#       <th>exonCount</th>
#       <th>exonStarts</th>
#       <th>exonEnds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>    Zfp78</td>
#       <td> NM_001112805</td>
#       <td>  chr7</td>
#       <td> +</td>
#       <td>   6316014</td>
#       <td>   6335315</td>
#       <td>   6324070</td>
#       <td>   6332201</td>
#       <td>  4</td>
#       <td>                  6316014,6324012,6325833,6330918,</td>
#       <td>                  6316054,6324103,6325960,6335315,</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>  Ralgps2</td>
#       <td> NM_001159967</td>
#       <td>  chr1</td>
#       <td> -</td>
#       <td> 158734296</td>
#       <td> 158869757</td>
#       <td> 158739294</td>
#       <td> 158837826</td>
#       <td> 19</td>
#       <td> 158734296,158741575,158743568,158747871,158749...</td>
#       <td> 158739324,158741667,158743674,158747964,158750...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>   Gm3286</td>
#       <td> NM_001122678</td>
#       <td>  chr5</td>
#       <td> +</td>
#       <td>  96221657</td>
#       <td>  96233254</td>
#       <td>  96229750</td>
#       <td>  96232820</td>
#       <td>  4</td>
#       <td>              96221657,96229723,96230701,96232252,</td>
#       <td>              96221749,96230037,96231292,96233254,</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>   Mrpl15</td>
#       <td>    NR_033530</td>
#       <td>  chr1</td>
#       <td> -</td>
#       <td>   4763278</td>
#       <td>   4775807</td>
#       <td>   4775807</td>
#       <td>   4775807</td>
#       <td>  4</td>
#       <td>                  4763278,4767605,4772648,4775653,</td>
#       <td>                  4764597,4767729,4772814,4775807,</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>    Acin1</td>
#       <td> NM_001085473</td>
#       <td> chr14</td>
#       <td> -</td>
#       <td>  55260997</td>
#       <td>  55305768</td>
#       <td>  55261564</td>
#       <td>  55305617</td>
#       <td> 19</td>
#       <td> 55260997,55262560,55262777,55263284,55263520,5...</td>
#       <td> 55261885,55262661,55263102,55263392,55263628,5...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> Vmn1r163</td>
#       <td> NM_001166755</td>
#       <td>  chr7</td>
#       <td> +</td>
#       <td>  22617369</td>
#       <td>  22618293</td>
#       <td>  22617369</td>
#       <td>  22618293</td>
#       <td>  1</td>
#       <td>                                         22617369,</td>
#       <td>                                         22618293,</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>    Llgl1</td>
#       <td> NM_001159404</td>
#       <td> chr11</td>
#       <td> +</td>
#       <td>  60513191</td>
#       <td>  60527690</td>
#       <td>  60513362</td>
#       <td>  60526547</td>
#       <td> 21</td>
#       <td> 60513191,60516285,60518170,60518352,60519468,6...</td>
#       <td> 60513443,60516383,60518252,60518483,60519624,6...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>    Wnt7b</td>
#       <td> NM_001163633</td>
#       <td> chr15</td>
#       <td> -</td>
#       <td>  85365866</td>
#       <td>  85411159</td>
#       <td>  85367818</td>
#       <td>  85389429</td>
#       <td>  4</td>
#       <td>              85365866,85374098,85389332,85410680,</td>
#       <td>              85368298,85374370,85389559,85411159,</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>    Satb1</td>
#       <td> NM_001163632</td>
#       <td> chr17</td>
#       <td> -</td>
#       <td>  51875511</td>
#       <td>  51972615</td>
#       <td>  51879222</td>
#       <td>  51948578</td>
#       <td> 11</td>
#       <td> 51875511,51881970,51907216,51914530,51921936,5...</td>
#       <td> 51879738,51882174,51907372,51914743,51922391,5...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>   Nkx2-1</td>
#       <td> NM_001146198</td>
#       <td> chr12</td>
#       <td> -</td>
#       <td>  57632923</td>
#       <td>  57636093</td>
#       <td>  57634021</td>
#       <td>  57636047</td>
#       <td>  2</td>
#       <td>                                57632923,57635674,</td>
#       <td>                                57634767,57636093,</td>
#     </tr>
#   </tbody>
# </table>

# %%
swissreg_sites = pd.read_table("/data/adrian/Dropbox/Data/swissregulon/mm9_sites.gff", sep="\t", skiprows=1,
                               names=["chrom", "alg", "motif_type", 
                                      "start", "end", "score", "strand", "frame", "data"])

swissreg_sites["motif_name"] = swissreg_sites.apply( lambda x: urllib2.unquote( dict([a.split("=") for a in x["data"].split(";")])["Motif"] ), axis=1 )

# %%
r = dict([a.split("=") for a in swissreg_sites.data[0].split(";")])["Motif"]

# %%
r["Motif"].decode("utf-8")
# Out:
# u'TFAP2{A%2CC}.p2'

# %%
urllib2.unquote(r["Motif"])
# Out:
# 'TFAP2{A,C}.p2'

# %%
import IPython

# %%
IPython.display.HTML( swissreg_sites[0:10].to_html() )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>chrom</th>
#       <th>alg</th>
#       <th>motif_type</th>
#       <th>start</th>
#       <th>end</th>
#       <th>score</th>
#       <th>strand</th>
#       <th>frame</th>
#       <th>data</th>
#       <th>motif_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>  chr2</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td> 130231517</td>
#       <td> 130231525</td>
#       <td> 0.323837</td>
#       <td> +</td>
#       <td> .</td>
#       <td> ID=TFAP2{A%2CC}.p2-0;Name=TFAP2{A%2CC}.p2-0;Mo...</td>
#       <td>    TFAP2{A,C}.p2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> chr11</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td> 107409493</td>
#       <td> 107409500</td>
#       <td> 0.943532</td>
#       <td> -</td>
#       <td> .</td>
#       <td> ID=FOX{D1%2CD2}.p2-1;Name=FOX{D1%2CD2}.p2-1;Mo...</td>
#       <td>    FOX{D1,D2}.p2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> chr11</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td>  99199074</td>
#       <td>  99199088</td>
#       <td> 0.772519</td>
#       <td> +</td>
#       <td> .</td>
#       <td> ID=ZNF423.p2-2;Name=ZNF423.p2-2;Motif=ZNF423.p...</td>
#       <td>        ZNF423.p2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>  chr1</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td>  52687272</td>
#       <td>  52687283</td>
#       <td> 0.439824</td>
#       <td> -</td>
#       <td> .</td>
#       <td> ID=FOX{I1%2CJ2}.p2-3;Name=FOX{I1%2CJ2}.p2-3;Mo...</td>
#       <td>    FOX{I1,J2}.p2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>  chr8</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td>   3720550</td>
#       <td>   3720564</td>
#       <td> 0.014784</td>
#       <td> +</td>
#       <td> .</td>
#       <td> ID=ZNF423.p2-4;Name=ZNF423.p2-4;Motif=ZNF423.p...</td>
#       <td>        ZNF423.p2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> chr10</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td> 126957534</td>
#       <td> 126957546</td>
#       <td> 0.892575</td>
#       <td> -</td>
#       <td> .</td>
#       <td> ID=PATZ1.p2-5;Name=PATZ1.p2-5;Motif=PATZ1.p2;S...</td>
#       <td>         PATZ1.p2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>  chrY</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td>    623503</td>
#       <td>    623520</td>
#       <td> 0.386161</td>
#       <td> -</td>
#       <td> .</td>
#       <td> ID=ALX1.p2-6;Name=ALX1.p2-6;Motif=ALX1.p2;Sequ...</td>
#       <td>          ALX1.p2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td> chr14</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td> 122196981</td>
#       <td> 122196989</td>
#       <td> 0.989395</td>
#       <td> +</td>
#       <td> .</td>
#       <td> ID=TFAP2{A%2CC}.p2-7;Name=TFAP2{A%2CC}.p2-7;Mo...</td>
#       <td>    TFAP2{A,C}.p2</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>  chr5</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td> 122907668</td>
#       <td> 122907681</td>
#       <td> 0.889726</td>
#       <td> -</td>
#       <td> .</td>
#       <td> ID=HNF4A_NR2F1%2C2.p2-8;Name=HNF4A_NR2F1%2C2.p...</td>
#       <td> HNF4A_NR2F1,2.p2</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td> chr15</td>
#       <td> Motevo</td>
#       <td> TFBS</td>
#       <td>  34608147</td>
#       <td>  34608160</td>
#       <td> 0.940190</td>
#       <td> +</td>
#       <td> .</td>
#       <td> ID=SP1.p2-9;Name=SP1.p2-9;Motif=SP1.p2;Sequenc...</td>
#       <td>           SP1.p2</td>
#     </tr>
#   </tbody>
# </table>

# %%
swissreg_sites.to_csv("/data/adrian/Dropbox/Data/swissregulon/mm9_sites.tab", sep="\t", index=False)

# %%
swissreg_sites[0:100].apply( lambda x: x["data"], axis=1)
# Out:
# 0     ID=TFAP2{A%2CC}.p2-0;Name=TFAP2{A%2CC}.p2-0;Mo...
# 1     ID=FOX{D1%2CD2}.p2-1;Name=FOX{D1%2CD2}.p2-1;Mo...
# 2     ID=ZNF423.p2-2;Name=ZNF423.p2-2;Motif=ZNF423.p...
# 3     ID=FOX{I1%2CJ2}.p2-3;Name=FOX{I1%2CJ2}.p2-3;Mo...
# 4     ID=ZNF423.p2-4;Name=ZNF423.p2-4;Motif=ZNF423.p...
# 5     ID=PATZ1.p2-5;Name=PATZ1.p2-5;Motif=PATZ1.p2;S...
# 6     ID=ALX1.p2-6;Name=ALX1.p2-6;Motif=ALX1.p2;Sequ...
# 7     ID=TFAP2{A%2CC}.p2-7;Name=TFAP2{A%2CC}.p2-7;Mo...
# 8     ID=HNF4A_NR2F1%2C2.p2-8;Name=HNF4A_NR2F1%2C2.p...
# 9     ID=SP1.p2-9;Name=SP1.p2-9;Motif=SP1.p2;Sequenc...
# 10    ID=SNAI1..3.p2-10;Name=SNAI1..3.p2-10;Motif=SN...
# 11    ID=TFDP1.p2-11;Name=TFDP1.p2-11;Motif=TFDP1.p2...
# 12    ID=FOX{F1%2CF2%2CJ1}.p2-12;Name=FOX{F1%2CF2%2C...
# 13    ID=NFE2L2.p2-13;Name=NFE2L2.p2-13;Motif=NFE2L2...
# 14    ID=ETS1%2C2.p2-14;Name=ETS1%2C2.p2-14;Motif=ET...
# ...
# 85    ID=ELF1%2C2%2C4.p2-85;Name=ELF1%2C2%2C4.p2-85;...
# 86    ID=NRF1.p2-86;Name=NRF1.p2-86;Motif=NRF1.p2;Se...
# 87    ID=MTF1.p2-87;Name=MTF1.p2-87;Motif=MTF1.p2;Se...
# 88    ID=SRY.p2-88;Name=SRY.p2-88;Motif=SRY.p2;Seque...
# 89    ID=SNAI1..3.p2-89;Name=SNAI1..3.p2-89;Motif=SN...
# 90    ID=HOX{A4%2CD4}.p2-90;Name=HOX{A4%2CD4}.p2-90;...
# 91    ID=GLI1..3.p2-91;Name=GLI1..3.p2-91;Motif=GLI1...
# 92    ID=CREB1.p2-92;Name=CREB1.p2-92;Motif=CREB1.p2...
# 93    ID=MYFfamily.p2-93;Name=MYFfamily.p2-93;Motif=...
# 94    ID=TFAP2{A%2CC}.p2-94;Name=TFAP2{A%2CC}.p2-94;...
# 95    ID=SNAI1..3.p2-95;Name=SNAI1..3.p2-95;Motif=SN...
# 96    ID=E2F1..5.p2-96;Name=E2F1..5.p2-96;Motif=E2F1...
# 97    ID=MAZ.p2-97;Name=MAZ.p2-97;Motif=MAZ.p2;Seque...
# 98    ID=SNAI1..3.p2-98;Name=SNAI1..3.p2-98;Motif=SN...
# 99    ID=KLF4.p3-99;Name=KLF4.p3-99;Motif=KLF4.p3;Se...
# Length: 100, dtype: object

# %%
mat_tf = []
for l in open("/data/adrian/Dropbox/Data/swissregulon/mat_TF_associations.mm").readlines():
    fields = l.split("\t")
    motif = fields[0]
    tfs = fields[2:]
    for tf in tfs:
        tfdata = tf.split(":")
        mat_tf.append( {"motif_name" : motif,
                        "tf_id_to_knownbind" : tfdata[0], 
                        "tf_entrez_gene_id" : tfdata[1], 
                        "tf_symbol" : tfdata[2],
                        "tf_description" : tfdata[3] } )
mat_tf = pd.DataFrame(mat_tf)

# %%
mat_tf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357 entries, 0 to 356
# Data columns (total 5 columns):
# motif_name            357  non-null values
# tf_description        357  non-null values
# tf_entrez_gene_id     357  non-null values
# tf_id_to_knownbind    357  non-null values
# tf_symbol             357  non-null values
# dtypes: object(5)
