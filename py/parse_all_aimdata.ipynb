# %%
import xlrd
import pandas as pd

# %%
a = xlrd.open_workbook("/data/adrian/Dropbox/Projects/Broad/PD_mouse/Final AIMs scoring.xls")
print a.sheet_names()

# %% [markdown]
# ## Parse Excel Sheets with AIMs Observations

# %%
# parse the low dose AIM spreadsheet
sh = a.sheet_by_name(u"low dose")
lowdose = []

for row in range(sh.nrows):
    # update the current day
    if type(sh.cell(rowx=row, colx=0).value) == unicode and sh.cell(rowx=row, colx=0).value[0:3] == "DAY":
        (day, dose) = sh.cell(rowx=row, colx=0).value.split("_")
        print day, dose
       
    print sh.cell(rowx=row, colx=0).value, type(sh.cell(rowx=row, colx=0).value)
    if (type(sh.cell(rowx=row, colx=0).value) == unicode or type(sh.cell(rowx=row, colx=0).value) == unicode) and len(sh.cell(rowx=row, colx=0).value.split("-")) == 2:
        (mouse_type, mouse_id) = sh.cell(rowx=row, colx=0).value.split("-")
        #    print sh.cell(rowx=row, colx=0).value

        
    for col in range(1, sh.ncols):
        if type(sh.cell(rowx=0, colx=col).value) == unicode and sh.cell(rowx=0, colx=col).value.split(" ")[1] == "min":
            curtime = sh.cell(rowx=0, colx=col).value.split(" ")[0]

        if type(sh.cell(rowx=row, colx=0).value) == unicode and len(sh.cell(rowx=row, colx=0).value.split("-")) == 2:
            if len(sh.cell(rowx=1, colx=col).value) > 0:
                measurement_type = sh.cell(rowx=1, colx=col).value
                val = sh.cell(rowx=row, colx=col).value
                if val != "":
                    lowdose.append( { "day" : day[3], "measurement_time" : curtime, 
                                     "dose" : dose, "mouse_type" : mouse_type, "mouse_id" : mouse_id, 
                                      "measurement_type" : measurement_type, "val" : val } )
        
lowdose = pd.DataFrame(lowdose)
# Out:
# DAY1 1mg/Kg
# DAY1_1mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1281 <type 'unicode'>
# CP101-1438 <type 'unicode'>
# CP101-1426 <type 'unicode'>
# CP101-1577 <type 'unicode'>
# CP101-1436 <type 'unicode'>
# CP101-1446 <type 'unicode'>
# CP101-1272 <type 'unicode'>
# CP101-1343 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1582 <type 'unicode'>
# CP73-1784 <type 'unicode'>
# CP73-1655 <type 'unicode'>
# CP73-1628 <type 'unicode'>
# CP73-1561 <type 'unicode'>
# CP73-1834 <type 'unicode'>
# CP73-1710 <type 'unicode'>
# CP73-1879 <type 'unicode'>
# CP73-1825 <type 'unicode'>
# CP73-1839 <type 'unicode'>
# CP73-1535 <type 'unicode'>
# CP73-1718 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
#  <type 'str'>
#  <type 'str'>
# DAY3 1mg/Kg
# DAY3_1mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1281 <type 'unicode'>
# CP101-1438 <type 'unicode'>
# CP101-1426 <type 'unicode'>
# CP101-1577 <type 'unicode'>
# CP101-1436 <type 'unicode'>
# CP101-1446 <type 'unicode'>
# CP101-1272 <type 'unicode'>
# CP101-1343 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1582 <type 'unicode'>
# CP73-1784 <type 'unicode'>
# CP73-1655 <type 'unicode'>
# CP73-1628 <type 'unicode'>
# CP73-1561 <type 'unicode'>
# CP73-1834 <type 'unicode'>
# CP73-1710 <type 'unicode'>
# CP73-1879 <type 'unicode'>
# CP73-1825 <type 'unicode'>
# CP73-1839 <type 'unicode'>
# CP73-1535 <type 'unicode'>
# CP73-1718 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# DAY4 2mg/Kg
# DAY4_2mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1281 <type 'unicode'>
# CP101-1438 <type 'unicode'>
# CP101-1426 <type 'unicode'>
# CP101-1577 <type 'unicode'>
# CP101-1436 <type 'unicode'>
# CP101-1446 <type 'unicode'>
# CP101-1272 <type 'unicode'>
# CP101-1343 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1582 <type 'unicode'>
# CP73-1784 <type 'unicode'>
# CP73-1655 <type 'unicode'>
# CP73-1628 <type 'unicode'>
# CP73-1561 <type 'unicode'>
# CP73-1834 <type 'unicode'>
# CP73-1710 <type 'unicode'>
# CP73-1879 <type 'unicode'>
# CP73-1825 <type 'unicode'>
# CP73-1839 <type 'unicode'>
# CP73-1535 <type 'unicode'>
# CP73-1718 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# DAY6 2mg/Kg
# DAY6_2mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1281 <type 'unicode'>
# CP101-1438 <type 'unicode'>
# CP101-1426 <type 'unicode'>
# CP101-1577 <type 'unicode'>
# CP101-1436 <type 'unicode'>
# CP101-1446 <type 'unicode'>
# CP101-1272 <type 'unicode'>
# CP101-1343 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1582 <type 'unicode'>
# CP73-1784 <type 'unicode'>
# CP73-1655 <type 'unicode'>
# CP73-1628 <type 'unicode'>
# CP73-1561 <type 'unicode'>
# CP73-1834 <type 'unicode'>
# CP73-1710 <type 'unicode'>
# CP73-1879 <type 'unicode'>
# CP73-1825 <type 'unicode'>
# CP73-1839 <type 'unicode'>
# CP73-1535 <type 'unicode'>
# CP73-1718 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
#  <type 'str'>
# DAY8 2mg/Kg
# DAY8_2mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1281 <type 'unicode'>
# CP101-1438 <type 'unicode'>
# CP101-1426 <type 'unicode'>
# CP101-1577 <type 'unicode'>
# CP101-1436 <type 'unicode'>
# CP101-1446 <type 'unicode'>
# CP101-1272 <type 'unicode'>
# CP101-1343 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1582 <type 'unicode'>
# CP73-1784 <type 'unicode'>
# CP73-1655 <type 'unicode'>
# CP73-1628 <type 'unicode'>
# CP73-1561 <type 'unicode'>
# CP73-1834 <type 'unicode'>
# CP73-1710 <type 'unicode'>
# CP73-1879 <type 'unicode'>
# CP73-1825 <type 'unicode'>
# CP73-1839 <type 'unicode'>
# CP73-1535 <type 'unicode'>
# CP73-1718 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>

# %%
# parse the high dose AIM spreadsheet
sh = a.sheet_by_name(u"high dose")
highdose = []

for row in range(sh.nrows):
    # update the current day
    if type(sh.cell(rowx=row, colx=0).value) == unicode and sh.cell(rowx=row, colx=0).value[0:3] == "DAY":
        (day, dose) = sh.cell(rowx=row, colx=0).value.split("_")
#        print day, dose
       
    print sh.cell(rowx=row, colx=0).value, type(sh.cell(rowx=row, colx=0).value)
    if (type(sh.cell(rowx=row, colx=0).value) == unicode or type(sh.cell(rowx=row, colx=0).value) == unicode) and len(sh.cell(rowx=row, colx=0).value.split("-")) == 2:
        (mouse_type, mouse_id) = sh.cell(rowx=row, colx=0).value.split("-")
        #    print sh.cell(rowx=row, colx=0).value

        
    for col in range(1, sh.ncols):
        if type(sh.cell(rowx=0, colx=col).value) == unicode and sh.cell(rowx=0, colx=col).value.split(" ")[1] == "min":
            curtime = sh.cell(rowx=0, colx=col).value.split(" ")[0]

        if type(sh.cell(rowx=row, colx=0).value) == unicode and len(sh.cell(rowx=row, colx=0).value.split("-")) == 2:
            if len(sh.cell(rowx=1, colx=col).value) > 0:
                measurement_type = sh.cell(rowx=1, colx=col).value
                val = sh.cell(rowx=row, colx=col).value
                if val != "":
                    highdose.append( { "day" : day[3], "measurement_time" : curtime, 
                                     "dose" : dose, "mouse_type" : mouse_type, "mouse_id" : mouse_id, 
                                      "measurement_type" : measurement_type, "val" : val } )
                else:
                    highdose.append( { "day" : day[3], "measurement_time" : curtime, 
                                     "dose" : dose, "mouse_type" : mouse_type, "mouse_id" : mouse_id, 
                                      "measurement_type" : measurement_type, "val" : 0 } )
                    
highdose = pd.DataFrame(highdose)
# Out:
# DAY1_3mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1423 <type 'unicode'>
# CP101-1290 <type 'unicode'>
# CP101-1428 <type 'unicode'>
# CP101-1557 <type 'unicode'>
# CP101-1288 <type 'unicode'>
# CP101-1340 <type 'unicode'>
# CP101-1597 <type 'unicode'>
# CP101-1280 <type 'unicode'>
# CP101-1205 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1511 <type 'unicode'>
# CP73-1832 <type 'unicode'>
# CP73-1721 <type 'unicode'>
# CP73-1542 <type 'unicode'>
# CP73-1579 <type 'unicode'>
# CP73-1804 <type 'unicode'>
# CP73-1841 <type 'unicode'>
# CP73-1836 <type 'unicode'>
# CP73-1665 <type 'unicode'>
# CP73-1857 <type 'unicode'>
# CP73-1876 <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# DAY3_3mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1423 <type 'unicode'>
# CP101-1290 <type 'unicode'>
# CP101-1428 <type 'unicode'>
# CP101-1557 <type 'unicode'>
# CP101-1288 <type 'unicode'>
# CP101-1340 <type 'unicode'>
# CP101-1597 <type 'unicode'>
# CP101-1280 <type 'unicode'>
# CP101-1205 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1511 <type 'unicode'>
# CP73-1832 <type 'unicode'>
# CP73-1721 <type 'unicode'>
# CP73-1542 <type 'unicode'>
# CP73-1579 <type 'unicode'>
# CP73-1804 <type 'unicode'>
# CP73-1841 <type 'unicode'>
# CP73-1836 <type 'unicode'>
# CP73-1665 <type 'unicode'>
# CP73-1857 <type 'unicode'>
# CP73-1876 <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# DAY4_6mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1423 <type 'unicode'>
# CP101-1290 <type 'unicode'>
# CP101-1428 <type 'unicode'>
# CP101-1557 <type 'unicode'>
# CP101-1288 <type 'unicode'>
# CP101-1340 <type 'unicode'>
# CP101-1597 <type 'unicode'>
# CP101-1280 <type 'unicode'>
# CP101-1205 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1511 <type 'unicode'>
# CP73-1832 <type 'unicode'>
# CP73-1721 <type 'unicode'>
# CP73-1542 <type 'unicode'>
# CP73-1579 <type 'unicode'>
# CP73-1804 <type 'unicode'>
# CP73-1841 <type 'unicode'>
# CP73-1836 <type 'unicode'>
# CP73-1665 <type 'unicode'>
# CP73-1857 <type 'unicode'>
# CP73-1876 <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
#  <type 'str'>
# DAY6_6mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1423 <type 'unicode'>
# CP101-1290 <type 'unicode'>
# CP101-1428 <type 'unicode'>
# CP101-1557 <type 'unicode'>
# CP101-1288 <type 'unicode'>
# CP101-1340 <type 'unicode'>
# CP101-1597 <type 'unicode'>
# CP101-1280 <type 'unicode'>
# CP101-1205 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1511 <type 'unicode'>
# CP73-1832 <type 'unicode'>
# CP73-1721 <type 'unicode'>
# CP73-1542 <type 'unicode'>
# CP73-1579 <type 'unicode'>
# CP73-1804 <type 'unicode'>
# CP73-1841 <type 'unicode'>
# CP73-1836 <type 'unicode'>
# CP73-1665 <type 'unicode'>
# CP73-1857 <type 'unicode'>
# CP73-1876 <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
#  <type 'str'>
#  <type 'str'>
# DAY8_6mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP101 <type 'unicode'>
# CP101-1423 <type 'unicode'>
# CP101-1290 <type 'unicode'>
# CP101-1428 <type 'unicode'>
# CP101-1557 <type 'unicode'>
# CP101-1288 <type 'unicode'>
# CP101-1340 <type 'unicode'>
# CP101-1597 <type 'unicode'>
# CP101-1280 <type 'unicode'>
# CP101-1205 <type 'unicode'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>
#  <type 'str'>
# CP73 <type 'unicode'>
# CP73-1511 <type 'unicode'>
# CP73-1832 <type 'unicode'>
# CP73-1721 <type 'unicode'>
# CP73-1542 <type 'unicode'>
# CP73-1579 <type 'unicode'>
# CP73-1804
#  <type 'unicode'>
# CP73-1841 <type 'unicode'>
# CP73-1836 <type 'unicode'>
# CP73-1665 <type 'unicode'>
# CP73-1857 <type 'unicode'>
# CP73-1876 <type 'unicode'>
#  <type 'str'>
#  <type 'str'>
# MEAN <type 'unicode'>
# STDEV <type 'unicode'>
# SEM <type 'unicode'>

# %%
# parse the acute group spreadsheet
sh = a.sheet_by_name(u"Acute high")
acute = []

for row in range(sh.nrows):
    # update the current day
    if type(sh.cell(rowx=row, colx=0).value) == unicode and sh.cell(rowx=row, colx=0).value[0:3] == "DAY":
        (day, dose) = sh.cell(rowx=row, colx=0).value.split("_")
#        print day, dose
       
    print sh.cell(rowx=row, colx=0).value, type(sh.cell(rowx=row, colx=0).value)
    if (type(sh.cell(rowx=row, colx=0).value) == unicode or type(sh.cell(rowx=row, colx=0).value) == unicode) and len(sh.cell(rowx=row, colx=0).value.split("-")) == 2:
        (mouse_type, mouse_id) = sh.cell(rowx=row, colx=0).value.split("-")
        #    print sh.cell(rowx=row, colx=0).value

        
    for col in range(1, sh.ncols):
        if type(sh.cell(rowx=0, colx=col).value) == unicode and sh.cell(rowx=0, colx=col).value.split(" ")[1] == "min":
            curtime = sh.cell(rowx=0, colx=col).value.split(" ")[0]

        if type(sh.cell(rowx=row, colx=0).value) == unicode and len(sh.cell(rowx=row, colx=0).value.split("-")) == 2:
            if len(sh.cell(rowx=1, colx=col).value) > 0:
                measurement_type = sh.cell(rowx=1, colx=col).value
                val = sh.cell(rowx=row, colx=col).value
                if val != "":
                    acute.append( { "day" : day[3], "measurement_time" : curtime, 
                                     "dose" : dose, "mouse_type" : mouse_type, "mouse_id" : mouse_id, 
                                      "measurement_type" : measurement_type, "val" : val } )
                else:
                    acute.append( { "day" : day[3], "measurement_time" : curtime, 
                                     "dose" : dose, "mouse_type" : mouse_type, "mouse_id" : mouse_id, 
                                      "measurement_type" : measurement_type, "val" : 0 } )

acute = pd.DataFrame(acute)
# Out:
# DAY1_6mg/Kg <type 'unicode'>
# MOUSE ID <type 'unicode'>
# CP73 <type 'unicode'>
# CP73-1649 <type 'unicode'>
# CP73-1501 <type 'unicode'>
# CP73-1492 <type 'unicode'>
# CP73-1604 <type 'unicode'>
# CP73-1659 <type 'unicode'>
# CP73-1735 <type 'unicode'>
# CP73-1580 <type 'unicode'>
# CP73-1739 <type 'unicode'>
# CP73-1802 <type 'unicode'>
# CP73-1698 <type 'unicode'>
# CP73-1881 <type 'unicode'>

# %% [markdown]
# ### Save aim data to csv file with the different score types as columns

# %%
(pd.pivot_table(highdose, rows=["day", "dose", "measurement_time", "mouse_id", "mouse_type"], cols="measurement_type", values="val")
    .reset_index().to_csv("/data/adrian/Dropbox/Projects/Broad/PD_mouse/aimdata/highdose_aim_byAimtype.csv"))

# %%
(pd.pivot_table(lowdose, rows=["day", "dose", "measurement_time", "mouse_id", "mouse_type"], cols="measurement_type", values="val")
    .reset_index().to_csv("/data/adrian/Dropbox/Projects/Broad/PD_mouse/lowdose_aim_byAimtype.csv"))

# %%
 lowdose
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 0 to 2239
# Data columns:
# day                 2240  non-null values
# dose                2240  non-null values
# measurement_time    2240  non-null values
# measurement_type    2240  non-null values
# mouse_id            2240  non-null values
# mouse_type          2240  non-null values
# val                 2240  non-null values
# dtypes: float64(1), object(6)

# %%
lowdose.to_csv("/data/adrian/Dropbox/Projects/Broad/PD_mouse/lowdose_aimd_full.csv")

# %%
d = lowdose.select(lambda x: lowdose.measurement_type[x] == "Lo" and lowdose.mouse_type[x] == "CP73")

# %% [markdown]
# ## function to make AIM plots

# %%
def plot_aim_data(aim_data, dosegroup_name, cptype):    
    # get the sort order for all the individuals by the total sum, so that 
    # we can keep the order / colors consistent on all the plots
    series = (aim_data.select(lambda x: aim_data.mouse_type[x] == cptype)
                    .groupby(["mouse_type", "mouse_id","day"])
                    .sum().unstack().transpose())
    
    # get grand totals and sort individuals in that order
    z = series.sum()
    o = z.order(ascending=False)
    
    fig_components = figure() 
    
    fig_components.set_size_inches(25, 6)
    fig_components.suptitle("AIM subcomponents vs. time by individual mouse - %(dosegroup_name)s, %(cptype)s" 
                                            % { "dosegroup_name" : dosegroup_name, "cptype" : cptype } )
    for (i, mtype) in enumerate(aim_data.measurement_type.unique()):
        ax = fig_components.add_subplot(1,5,i+1)
        ax.set_axis_bgcolor("#F2F2F2")
        ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 12)])
        title(mtype)
        d = aim_data.select(lambda x: aim_data.measurement_type[x] == mtype and aim_data.mouse_type[x] == cptype)
        grouped = d.groupby(["mouse_type", "mouse_id"])
        for g in o.index:
            daygroups = grouped.get_group(g).groupby("day")
            ax.plot(daygroups.sum(), ".-", label=g[0] + " #" + g[1], ms=17, lw=2.5)
            ax.set_ylim((-1, 22))
            ax.set_xticks(range(len(daygroups.sum().index))) 
            ax.set_xticklabels(daygroups.sum().index)
            ax.set_ylabel("AIM score - sum over the 6 measurements")
            ax.set_xlabel("day")
        grid()
    l = ax.legend(bbox_to_anchor=(1.05, 0), loc='lower left', borderaxespad=0., title="individual mouse")        
    l.legendPatch.set_fc("#F2F2F2")
    
    
    fig_LiLoAxOl_summary = figure()
    ax = fig_LiLoAxOl_summary.add_subplot(1,2,1)
    title("Composite (summed) LiLoAxOl AIM score \n by individual by day, %(dosegroup_name)s, %(cptype)s" 
            % { "dosegroup_name" : dosegroup_name, "cptype" : cptype } )
    ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 12)])
    ax.set_ylim(-5, 60)
    ax.set_xlim(-0.5, 4.5)
    ax.set_axis_bgcolor("#F2F2F2")
    series = (aim_data.select(lambda x: aim_data.mouse_type[x] == cptype)
                    .groupby(["mouse_type", "mouse_id","day"])
                    .sum().unstack().transpose())
    lines = ax.plot( series[o.index],  "o-", ms=12, lw=2.5)
    ax.set_xticks(range(len(series.ix["val"].index)))
    ax.set_xticklabels(series.ix["val"].index)
    ax.set_xlabel("day")
    ax.set_ylabel("composite AIM score")
    grid()
    
    ax = fig_LiLoAxOl_summary.add_subplot(1,6,4)
    title("Sum (over time) of composite LiLoAxOl AIM score by individual, \n %(dosegroup_name)s, %(cptype)s"
            % { "dosegroup_name" : dosegroup_name, "cptype" : cptype } )
    ax.set_xlim(-0.5, 0.5)
    ax.set_ylim(-5, 200)
    ax.set_axis_bgcolor("#F2F2F2")
    ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 12)])
    for v in o:
        ax.plot(v, "s", ms=10, alpha=0.7)
    grid()
    xlabel("")
    ax.set_ylabel("Total AIM score")
    ax.set_xticks([])
    ax.set_yticks(arange(0, 200, 10))
    l = ax.legend( lines, [g[0] + " #" + g[1] for g in o.index], bbox_to_anchor=(1.3, 0), loc='lower left', borderaxespad=0., title="individual mouse")
    l.legendPatch.set_fc("#F2F2F2")
    
    # li / ax / Ol
    fig_LiAxOl_summary = figure()
    ax = fig_LiAxOl_summary.add_subplot(1,2,1)
    title("Composite (summed) AIM LiAxOl score \n by individual by day, %(dosegroup_name)s, %(cptype)s"
            % { "dosegroup_name" : dosegroup_name, "cptype" : cptype } )
    ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 12)])
    ax.set_ylim(-5, 60)
    ax.set_xlim(-0.5, 4.5)
    ax.set_axis_bgcolor("#F2F2F2")
    series = (aim_data.select(lambda x: aim_data.mouse_type[x] == cptype and aim_data.measurement_type[x] in set(["Li", "Ax", "Ol"]))
                    .groupby(["mouse_type", "mouse_id","day"])
                    .sum().unstack().transpose())
    lines = ax.plot( series[o.index],  "o-", ms=12, lw=2.5)
    ax.set_xticks(range(len(series.ix["val"].index)))
    ax.set_xticklabels(series.ix["val"].index)
    ax.set_xlabel("day")
    ax.set_ylabel("composite AIM score")
    grid()
    
    ax = fig_LiAxOl_summary.add_subplot(1,6,4)
    title("Sum (over time) of composite LiAxOl AIM score by individual, \n %(dosegroup_name)s, %(cptype)s"
            % { "dosegroup_name" : dosegroup_name, "cptype" : cptype } )
    ax.set_xlim(-0.5, 0.5)
    ax.set_ylim(-5, 175)
    ax.set_axis_bgcolor("#F2F2F2")
    ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 12)])
    for v in series.sum()[o.index]:
        ax.plot(v, "s", ms=10, alpha=0.7)
    grid()
    xlabel("")
    ax.set_ylabel("Total AIM score")
    ax.set_yticks(arange(0, 160, 10))
    ax.set_xticks([])
    l = ax.legend( lines, [g[0] + " #" + g[1] for g in o.index], bbox_to_anchor=(1.3, 0), loc='lower left', borderaxespad=0., title="individual mouse")
    l.legendPatch.set_fc("#F2F2F2")

    return [fig_components, fig_LiLoAxOl_summary, fig_LiAxOl_summary]

# %% [markdown]
# ### Generate and save pdf plots for each subgroup

# %% [markdown]
# ### Chronic Low Dose / CP101

# %%
from matplotlib.backends.backend_pdf import PdfPages
pdf_pages = PdfPages("/data/adrian/Dropbox/Projects/Broad/PD_mouse/results/March25/chronic_lowdose_cp101.pdf")
for p in plot_aim_data( aim_data = lowdose, dosegroup_name = "Chronic Low Dose", cptype = "CP101"):
    pdf_pages.savefig(p)
pdf_pages.close()

# %% [markdown]
# ### Chronic Low Dose / CP73

# %%
from matplotlib.backends.backend_pdf import PdfPages
pdf_pages = PdfPages("/data/adrian/Dropbox/Projects/Broad/PD_mouse/results/March25/chronic_lowdose_cp73.pdf")
for p in plot_aim_data( aim_data = lowdose, dosegroup_name = "Chronic Low Dose", cptype = "CP73"):
    pdf_pages.savefig(p)
pdf_pages.close()

# %% [markdown]
# ### Chronic High Dose / CP101

# %%
from matplotlib.backends.backend_pdf import PdfPages
pdf_pages = PdfPages("/data/adrian/Dropbox/Projects/Broad/PD_mouse/results/March25/chronic_highdose_cp101.pdf")
for p in plot_aim_data( aim_data = highdose, dosegroup_name = "Chronic High Dose", cptype = "CP101"):
    pdf_pages.savefig(p)
pdf_pages.close()

# %% [markdown]
# ### Chronic High Dose / CP73

# %%
from matplotlib.backends.backend_pdf import PdfPages
pdf_pages = PdfPages("/data/adrian/Dropbox/Projects/Broad/PD_mouse/results/March25/chronic_highdose_cp73.pdf")
for p in plot_aim_data( aim_data = highdose, dosegroup_name = "Chronic High Dose", cptype = "CP73"):
    pdf_pages.savefig(p)
pdf_pages.close()

# %%
v = lowdose.groupby(["mouse_type","mouse_id","measurement_type"]).sum().unstack().ix["CP73", :]

# %%
ts = lowdose.groupby(["mouse_type","mouse_id", "day", "measurement_type"]).sum().unstack().ix["CP73"].unstack()["val"].transpose()

# %%
ts.ix["Ax"]
# Out:
# mouse_id  1535  1561  1582  1628  1655  1710  1718  1784  1825  1834  1839  1879
# day
# 1          0.0   0.0   0.0   3.0     1     0     0   0.0   0.0   0.5   0.0   2.0
# 3          0.0   0.0   1.0   1.5     2     0     0   1.5   0.0   4.5   0.0   4.0
# 4          7.0   2.0   3.5   6.0     7     4     1   6.0   6.0   9.0   5.0  11.0
# 6          4.0   6.0   6.0   6.0     5     6     4   6.0   7.0   8.0   5.5   8.5
# 8          6.5   6.5   6.0   8.0     6     7     4   7.5   8.5   9.5   7.5   9.0

# %%
scatter_matrix(lowdose.groupby(["mouse_type","mouse_id","measurement_type"]).sum().unstack().ix["CP101", "val"])
# Out:
# array([[Axes(0.125,0.70625;0.19375x0.19375),
#         Axes(0.31875,0.70625;0.19375x0.19375),
#         Axes(0.5125,0.70625;0.19375x0.19375),
#         Axes(0.70625,0.70625;0.19375x0.19375)],
#        [Axes(0.125,0.5125;0.19375x0.19375),
#         Axes(0.31875,0.5125;0.19375x0.19375),
#         Axes(0.5125,0.5125;0.19375x0.19375),
#         Axes(0.70625,0.5125;0.19375x0.19375)],
#        [Axes(0.125,0.31875;0.19375x0.19375),
#         Axes(0.31875,0.31875;0.19375x0.19375),
#         Axes(0.5125,0.31875;0.19375x0.19375),
#         Axes(0.70625,0.31875;0.19375x0.19375)],
#        [Axes(0.125,0.125;0.19375x0.19375),
#         Axes(0.31875,0.125;0.19375x0.19375),
#         Axes(0.5125,0.125;0.19375x0.19375),
#         Axes(0.70625,0.125;0.19375x0.19375)]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
figsize(15, 15)
matplotlib.rcParams.update({'font.size' : 20 })
scatter_matrix(v["val"], marker="O")
# Out:
# array([[Axes(0.125,0.70625;0.19375x0.19375),
#         Axes(0.31875,0.70625;0.19375x0.19375),
#         Axes(0.5125,0.70625;0.19375x0.19375),
#         Axes(0.70625,0.70625;0.19375x0.19375)],
#        [Axes(0.125,0.5125;0.19375x0.19375),
#         Axes(0.31875,0.5125;0.19375x0.19375),
#         Axes(0.5125,0.5125;0.19375x0.19375),
#         Axes(0.70625,0.5125;0.19375x0.19375)],
#        [Axes(0.125,0.31875;0.19375x0.19375),
#         Axes(0.31875,0.31875;0.19375x0.19375),
#         Axes(0.5125,0.31875;0.19375x0.19375),
#         Axes(0.70625,0.31875;0.19375x0.19375)],
#        [Axes(0.125,0.125;0.19375x0.19375),
#         Axes(0.31875,0.125;0.19375x0.19375),
#         Axes(0.5125,0.125;0.19375x0.19375),
#         Axes(0.70625,0.125;0.19375x0.19375)]], dtype=object)

# %%
figsize(5,5)
plot( v[("val", "Ax")], v[("val", "Li")], ".")

# %%
""daygroups.sum()
# Out:
#      val
# day
# 1      1
# 3      3
# 4      8
# 6      8
# 8     10

# %%
lowdose.select(lambda x: lowdose.measurement_type[x] == "Lo")
# Out:
#      day    dose measurement_time measurement_type mouse_id mouse_type  val
# 0      1  1mg/Kg               20               Lo     1281      CP101    1
# 4      1  1mg/Kg               40               Lo     1281      CP101    1
# 8      1  1mg/Kg               60               Lo     1281      CP101    1
# 12     1  1mg/Kg               80               Lo     1281      CP101    0
# 16     1  1mg/Kg              100               Lo     1281      CP101    0
# 20     1  1mg/Kg              120               Lo     1281      CP101    0
# 24     1  1mg/Kg               20               Lo     1438      CP101    0
# 28     1  1mg/Kg               40               Lo     1438      CP101    0
# 32     1  1mg/Kg               60               Lo     1438      CP101    0
# 36     1  1mg/Kg               80               Lo     1438      CP101    0
# 40     1  1mg/Kg              100               Lo     1438      CP101    0
# 44     1  1mg/Kg              120               Lo     1438      CP101    0
# 48     1  1mg/Kg               20               Lo     1426      CP101  1.5
# 52     1  1mg/Kg               40               Lo     1426      CP101  1.5
# 56     1  1mg/Kg               60               Lo     1426      CP101  1.5
# 60     1  1mg/Kg               80               Lo     1426      CP101    0
# 64     1  1mg/Kg              100               Lo     1426      CP101    0
# 68     1  1mg/Kg              120               Lo     1426      CP101    0
# 72     1  1mg/Kg               20               Lo     1577      CP101    1
# 76     1  1mg/Kg               40               Lo     1577      CP101    1
# 80     1  1mg/Kg               60               Lo     1577      CP101    1
# 84     1  1mg/Kg               80               Lo     1577      CP101    0
# 88     1  1mg/Kg              100               Lo     1577      CP101    0
# 92     1  1mg/Kg              120               Lo     1577      CP101    0
# 96     1  1mg/Kg               20               Lo     1436      CP101    1
# 100    1  1mg/Kg               40               Lo     1436      CP101  1.5
# 104    1  1mg/Kg               60               Lo     1436      CP101    0
# 108    1  1mg/Kg               80               Lo     1436      CP101    0
# 112    1  1mg/Kg              100               Lo     1436      CP101    0
# 116    1  1mg/Kg              120               Lo     1436      CP101    0
# 120    1  1mg/Kg               20               Lo     1446      CP101    2
# 124    1  1mg/Kg               40               Lo     1446      CP101    1
# 128    1  1mg/Kg               60               Lo     1446      CP101    0
# 132    1  1mg/Kg               80               Lo     1446      CP101    0
# 1360   8  2mg/Kg              100               Lo     1281      CP101    0
# 1364   8  2mg/Kg              120               Lo     1281      CP101
# 1368   8  2mg/Kg               20               Lo     1438      CP101    2
# 1372   8  2mg/Kg               40               Lo     1438      CP101    2
# 1376   8  2mg/Kg               60               Lo     1438      CP101    2
# 1380   8  2mg/Kg               80               Lo     1438      CP101  1.5
# 1384   8  2mg/Kg              100               Lo     1438      CP101    1
# 1388   8  2mg/Kg              120               Lo     1438      CP101
# 1392   8  2mg/Kg               20               Lo     1426      CP101    2
# 1396   8  2mg/Kg               40               Lo     1426      CP101    2
# 1400   8  2mg/Kg               60               Lo     1426      CP101    2
# 1404   8  2mg/Kg               80               Lo     1426      CP101  1.5
# 1408   8  2mg/Kg              100               Lo     1426      CP101    0
# 1412   8  2mg/Kg              120               Lo     1426      CP101
# 1416   8  2mg/Kg               20               Lo     1577      CP101  1.5
# 1420   8  2mg/Kg               40               Lo     1577      CP101    1
# 1424   8  2mg/Kg               60               Lo     1577      CP101    1
# 1428   8  2mg/Kg               80               Lo     1577      CP101    1
# 1432   8  2mg/Kg              100               Lo     1577      CP101    0
# 1436   8  2mg/Kg              120               Lo     1577      CP101
# 1440   8  2mg/Kg               20               Lo     1436      CP101    2
# 1444   8  2mg/Kg               40               Lo     1436      CP101    2
# 1448   8  2mg/Kg               60               Lo     1436      CP101    2
# 1452   8  2mg/Kg               80               Lo     1436      CP101  0.5
# 1456   8  2mg/Kg              100               Lo     1436      CP101    0
# 1460   8  2mg/Kg              120               Lo     1436      CP101
# 1464   8  2mg/Kg               20               Lo     1446      CP101  1.5
# 1468   8  2mg/Kg               40               Lo     1446      CP101  1.5
# 1472   8  2mg/Kg               60               Lo     1446      CP101    1
# 1476   8  2mg/Kg               80               Lo     1446      CP101    1
# 1480   8  2mg/Kg              100               Lo     1446      CP101    1
# 1484   8  2mg/Kg              120               Lo     1446      CP101
# 1488   8  2mg/Kg               20               Lo     1272      CP101    2
# 1492   8  2mg/Kg               40               Lo     1272      CP101    2
# 1496   8  2mg/Kg               60               Lo     1272      CP101    2
# 1500   8  2mg/Kg               80               Lo     1272      CP101  1.5
# 1504   8  2mg/Kg              100               Lo     1272      CP101    0
# 1508   8  2mg/Kg              120               Lo     1272      CP101
# 1512   8  2mg/Kg               20               Lo     1343      CP101    0
# 1516   8  2mg/Kg               40               Lo     1343      CP101    0
# 1520   8  2mg/Kg               60               Lo     1343      CP101    0
# 1524   8  2mg/Kg               80               Lo     1343      CP101    0
# 1528   8  2mg/Kg              100               Lo     1343      CP101    0
# 1532   8  2mg/Kg              120               Lo     1343      CP101

# %%
o = acute.groupby(["mouse_type", "mouse_id"]).sum().sort_index(by="val", ascending=False)

# %%
o = acute.groupby(["mouse_type", "mouse_id"]).sum().sort_index(by="val", ascending=False)
fig_acute_cp73_subscores = figure()
fig_acute_cp73_subscores.suptitle("Acute L-DOPA CP73")
grouped = acute.groupby("measurement_type")
for i, g in enumerate(acute.groupby("measurement_type").groups):
    d = grouped.get_group(g)
    ax = fig_acute_cp73_subscores.add_subplot(1, 4, i+1)
    ax.set_title(g)
    ax.set_axis_bgcolor("#FAFAFA")
    ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 11)])
    lines = []
    d.index = d.mouse_id
    d = d.ix[o.ix["CP73"].index]
    color_cycle = ax._get_lines.color_cycle
    next_color = next(color_cycle)
#    ax.bar(range(len(d.index)), d.val,  )
    for (r, q) in enumerate(d.index):
        next_color = next(color_cycle)
        ax.bar(r, d.val[q], label=d.mouse_id[q], color=next_color)
        
#        ax.bar(float(d.measurement_time[q]) + (rand()*18-9),
#                 d.val[q], "s", ms=10, alpha=0.6, label=d.mouse_id[q])
    ax.set_xlim((-1, 12))
    ax.set_ylim(0, 3)
    ax.set_xticks(array(range(len(d.index)))+0.5)
    ax.set_xticklabels(d.index, rotation=90, size="medium")
    ax.set_xlabel("individual mouse")
    ax.set_ylabel("AIM subscore value")
    ax.grid()
#l = ax.legend( bbox_to_anchor=(1.3, 0), loc='lower left', borderaxespad=0., title="individual mouse")
#l.legendPatch.set_fc("#FAFAFA")

fig = figure()

# %%
#title("Sum (over time) of composite LiAxOl AIM score by individual, \n %(dosegroup_name)s, %(cptype)s"
#            % { "dosegroup_name" : dosegroup_name, "cptype" : cptype } )
fig_acute_cp73_LiLoAxOl = figure()
ax = fig_acute_cp73_LiLoAxOl.add_subplot(1,3,1)
ax.set_title("Acute CP73 Total AIM score LoOlAxLi")
ax.set_xlim(-0.5, 0.5)
ax.set_ylim(0, 10)
ax.set_axis_bgcolor("#F2F2F2")
ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 11)])

for (r, v) in enumerate(o.ix["CP73"].index):
        next_color = next(color_cycle)
        ax.bar(r, o.ix[("CP73", v)], label=v, color=next_color)

grid()
xlabel("individual mouse")
ax.set_xlim(-1,12)
ax.set_ylabel("Total AIM score")
ax.set_yticks(arange(0, 12, 1))
ax.set_xticks(array(range(len(o.ix["CP73"].index))) + 0.5)
ax.set_xticklabels(o.ix["CP73"].index, rotation=90, size="medium")
#l = ax.legend( bbox_to_anchor=(1.1, 0), loc='lower left', borderaxespad=0., title="individual mouse (score)")
#l.legendPatch.set_fc("#FAFAFA")


#l = ax.legend( lines, [g[0] + " #" + g[1] for g in o.index], bbox_to_anchor=(1.3, 0), loc='lower left', borderaxespad=0., title="individual mouse")
#l.legendPatch.set_fc("#F2F2F2")
# Out:
# [<matplotlib.text.Text at 0x54fca9d0>,
#  <matplotlib.text.Text at 0x54fd5050>,
#  <matplotlib.text.Text at 0x553342d0>,
#  <matplotlib.text.Text at 0x55334710>,
#  <matplotlib.text.Text at 0x55334dd0>,
#  <matplotlib.text.Text at 0x5532fdd0>,
#  <matplotlib.text.Text at 0x55336490>,
#  <matplotlib.text.Text at 0x55336b50>,
#  <matplotlib.text.Text at 0x55338250>,
#  <matplotlib.text.Text at 0x55338910>,
#  <matplotlib.text.Text at 0x55338fd0>]

# %%
o = acute.select(lambda x: acute.measurement_type[x] in ["Li", "Ax", "Ol"]).groupby(["mouse_type", "mouse_id"]).sum().sort_index(by="val", ascending=False)
fig_acute_cp73_LiAxOl = figure()
ax = fig_acute_cp73_LiAxOl.add_subplot(1,3,1)
ax.set_title("Acute CP73 Total AIM score LiAxOl")
ax.set_xlim(-0.5, 0.5)
ax.set_ylim(0, 10)
ax.set_axis_bgcolor("#F2F2F2")
ax.set_color_cycle([get_cmap("Paired")(k) for k in linspace(0, 1, 11)])

for (r, v) in enumerate(o.ix["CP73"].index):
        next_color = next(color_cycle)
        ax.bar(r, o.ix[("CP73", v)], label=v, color=next_color)

grid()
xlabel("individual mouse")
ax.set_xlim(-1,12)
ax.set_ylabel("Total AIM score")
ax.set_yticks(arange(0, 12, 1))
ax.set_xticks(array(range(len(o.ix["CP73"].index))) + 0.5)
ax.set_xticklabels(o.ix["CP73"].index, rotation=90, size="medium")
# Out:
# [<matplotlib.text.Text at 0x5344fb10>,
#  <matplotlib.text.Text at 0x5398d6d0>,
#  <matplotlib.text.Text at 0x53990650>,
#  <matplotlib.text.Text at 0x53990550>,
#  <matplotlib.text.Text at 0x52f39250>,
#  <matplotlib.text.Text at 0x53990b10>,
#  <matplotlib.text.Text at 0x53955390>,
#  <matplotlib.text.Text at 0x52770c50>,
#  <matplotlib.text.Text at 0x52770ed0>,
#  <matplotlib.text.Text at 0x52dea350>,
#  <matplotlib.text.Text at 0x52deaa10>]

# %%
from matplotlib.backends.backend_pdf import PdfPages
pdf_pages = PdfPages("/data/adrian/Dropbox/Projects/Broad/PD_mouse/results/March25/acute_highdose_cp73.pdf")
for p in [fig_acute_cp73_subscores,fig_acute_cp73_LiAxOl,fig_acute_cp73_LiLoAxOl]:
    pdf_pages.savefig(p, bbox_inches="tight")
pdf_pages.close()

# %%
d.index = d.mouse_id

# %%
d.index = d.mouse_id

# %%
d = d.ix[o.ix["CP73"].index]

# %%
d.sort_index
# Out:
#    day    dose measurement_time measurement_type mouse_id mouse_type  val
# 1    1  6mg/Kg               40               Li     1649       CP73  1.5
# 5    1  6mg/Kg               40               Li     1501       CP73  1.5
# 9    1  6mg/Kg               40               Li     1492       CP73  1.0
# 13   1  6mg/Kg               40               Li     1604       CP73  0.5
# 17   1  6mg/Kg               40               Li     1659       CP73  2.0
# 21   1  6mg/Kg               40               Li     1735       CP73  1.5
# 25   1  6mg/Kg               40               Li     1580       CP73  1.5
# 29   1  6mg/Kg               40               Li     1739       CP73  0.5
# 33   1  6mg/Kg               40               Li     1802       CP73  2.0
# 37   1  6mg/Kg               40               Li     1698       CP73  1.5
# 41   1  6mg/Kg               40               Li     1881       CP73  1.5

# %%
array([float(f) for f in d.measurement_time]) + [rand() for f in d.measurement_time
# Out:
# array([ 40.13778382,  40.07826614,  40.78851723,  40.20450105,
#         40.56193006,  40.66257897,  40.64398223,  40.12476707,
#         40.11271846,  40.65217841,  40.09406655])
